# %% [markdown]
# The code is designed to be executed within [Docker](https://github.com/nazarb/2025_levees_DL/blob/main/Setup/Setup.md).

# %% [markdown]
# # The SWIN UNETR model from MONAI
# The SWIN UNETR model was adapted from MONAI and adjusted to 2D version of the dataset

# %% [markdown]
# ## Load libraries

# %%
import os
import shutil
import tempfile
from tqdm import tqdm
import matplotlib.pyplot as plt
# %matplotlib inline

from monai.transforms import (
    AsDiscrete,
    Compose,
    CropForegroundd,
    LoadImaged,
    Orientationd,
    RandFlipd,
    RandCropByPosNegLabeld,
    RandShiftIntensityd,
    ScaleIntensityRanged,
    Spacingd,
    RandRotate90d,
    EnsureTyped,
)
from monai.data import (
    ThreadDataLoader,
    CacheDataset,
    load_decathlon_datalist,
    decollate_batch,
    set_track_meta,
)
from monai.inferers import sliding_window_inference
from monai.networks.nets import SwinUNETR, AttentionUnet
from monai.metrics import DiceMetric
from monai.losses import DiceCELoss
from monai.losses import DiceLoss, TverskyLoss, FocalLoss

import torch
import einops
import warnings




warnings.filterwarnings("ignore")
import torch
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.is_available() 
torch.cuda.device_count()
torch.cuda.current_device()
torch.cuda.get_device_name(0)
# Out:
# IProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html
# 'NVIDIA RTX A4000'

# %% [markdown]
# ### Check your location

# %%
# Check the amount of shared memory
os.system('df -h /dev/shm')

import os
dir = os.getcwd()
print('Current directory is:',dir)


warnings.filterwarnings("ignore")

# %% [markdown]
# ## Set the model parametres and predict

# %% [markdown]
# The code allows you to pick the image

# %%
import json
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import os
import rasterio
from rasterio.windows import Window
import tifffile as tiff


def get_filename_without_extension():
    data_to_detect = input("Enter the path to the image: ").strip('"')
    filename_to_detect = os.path.splitext(os.path.basename(data_to_detect))[0]
    return filename_to_detect
filename_to_detect = get_filename_without_extension()

class NumpyDataset(Dataset):
    def __init__(self, image_paths, label_data):
        self.image_paths = image_paths
        self.label_data = label_data  # Accept either paths or preloaded arrays

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = np.load(self.image_paths[idx])

        # Check if label_data contains paths or arrays
        if isinstance(self.label_data[idx], str):
            label = np.load(self.label_data[idx])
        else:
            label = self.label_data[idx]

        image = self.replace_nans_in_array(image)
        label = self.replace_nans_in_array(label)

        image = torch.tensor(image, dtype=torch.float32)
        label = torch.tensor(label, dtype=torch.float32)

        return image, label, self.image_paths[idx]

    @staticmethod
    def replace_nans_in_array(arr):
        arr[np.isnan(arr)] = 0
        arr[np.isinf(arr)] = 0
        return arr


def load_dataset_json(json_path):
    with open(json_path, 'r') as file:
        dataset_json = json.load(file)
    return dataset_json

def prepare_test_loader(test_image_paths, batch_size):
    dummy_label_dir = "./model/temp_labels/"
    if not os.path.exists(dummy_label_dir):
        os.makedirs(dummy_label_dir)

    test_labels = []
    for image_path in test_image_paths:
        dummy_label_path = os.path.join(dummy_label_dir, os.path.basename(image_path).replace('.npy', '_label.npy'))
        np.save(dummy_label_path, np.zeros_like(np.load(image_path)))
        test_labels.append(dummy_label_path)

    test_dataset = NumpyDataset(test_image_paths, test_labels)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

    return test_loader

def initialize_model():
    """Initialize the SwinUNETR model."""
    model = SwinUNETR(
        img_size=(96, 96),
        in_channels=48,
        out_channels=1,  # Use the passed `num_classes`
        use_checkpoint=True,
        feature_size=48,
        depths=(3, 9, 18, 3),
        num_heads=(4, 8, 16, 32),
        drop_rate=0.1,  # Added dropout
        attn_drop_rate=0.1,
        dropout_path_rate=0.2,
        spatial_dims=2
    )
    return model


def load_adapted_model(model, checkpoint_path):
    checkpoint = torch.load(checkpoint_path, map_location='cpu')
    model.load_state_dict(checkpoint, strict=False)
    return model

### Load model

def load_large_image(image_path):
    print(f"Loading large image from {image_path}")
    with rasterio.open(image_path) as src:
        image = src.read()
        transform = src.transform  # Capture the affine transformation matrix
    return image, transform

def split_to_tiles(image, tile_size, save_dir):
    print(f"Splitting image into tiles of size {tile_size}x{tile_size}")
    tiles = []
    num_channels, height, width = image.shape
    for i in range(0, height, tile_size):
        for j in range(0, width, tile_size):
            window = Window(j, i, tile_size, tile_size)
            tile = image[:, i:i+tile_size, j:j+tile_size]
            if tile.shape[1] == tile_size and tile.shape[2] == tile_size:
                tile_path = os.path.join(save_dir, f'tile_{i}_{j}.tif')
                print(f"Saving tile to {tile_path}")
                tiff.imwrite(tile_path, tile)
                tiles.append(tile_path)
    print(f"Total number of tiles: {len(tiles)}")
    return tiles

def convert_tiles_to_npy(tile_paths, npy_dir):
    if not os.path.exists(npy_dir):
        os.makedirs(npy_dir)
    npy_paths = []
    for tile_path in tile_paths:
        image = tiff.imread(tile_path)
        npy_path = os.path.join(npy_dir, os.path.basename(tile_path).replace('.tif', '.npy'))
        print(f"Converting {tile_path} to {npy_path}")
        np.save(npy_path, image)
        npy_paths.append(npy_path)
    return npy_paths

def merge_tiles(tiles, image_shape, tile_size):
    print(f"Merging tiles back into full image of shape {image_shape}")
    _, height, width = image_shape  # Assume image_shape is in the format (num_channels, height, width)
    full_image = np.zeros((height, width), dtype=np.uint8)  # Only one channel for the full image

    for tile_path in tiles:
        tile = tiff.imread(tile_path)
        # Adjust the parsing to match the filename pattern used in split_to_tiles
        filename = os.path.basename(tile_path)
        parts = filename.replace('tile_', '').replace('.tif', '').split('_')
        if len(parts) == 2:  # Ensure the filename format is correct
            i, j = map(int, parts)
            full_image[i:i+tile_size, j:j+tile_size] = tile  # Single channel tile assignment
        else:
            print(f"Unexpected filename format: {filename}")

    return full_image
### 

def predict_and_save(model, test_loader, device, tile_paths, save_dir='model/temp_pred'):
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    print(f"Starting prediction on device: {device}")
    model.eval()
    model.to(device)
    predictions = []

    with torch.no_grad():
        for batch_idx, batch in enumerate(test_loader):
            images, _, _ = batch  # Unpack the batch; labels and paths are not needed for predictions
            print(f"Predicting batch {batch_idx + 1}/{len(test_loader)}")
            print(f"Images type: {type(images)}, Images shape: {images.shape if isinstance(images, torch.Tensor) else 'unknown'}")

            images = images.to(device)  # Move images to the correct device
            outputs = model(images)
            outputs = torch.sigmoid(outputs)
            outputs = outputs.cpu().numpy()

            # Save the predictions for each image in the batch
            for i in range(images.shape[0]):
                output_image = outputs[i]
                binary_output = (output_image > 0.5).astype(np.uint8)  # Apply threshold to create binary output
                original_tile_name = os.path.basename(tile_paths[batch_idx * test_loader.batch_size + i]).replace('.npy', '.tif')
                save_path = os.path.join(save_dir, original_tile_name)
                print(f"Saving prediction to {save_path}")
                tiff.imwrite(save_path, binary_output)
                predictions.append(save_path)

    return predictions



def save_full_raster(predictions, image_shape, tile_size, save_path):
    print(f"Saving full raster to {save_path}")
    full_raster = merge_tiles(predictions, image_shape, tile_size)
    with rasterio.open(save_path, 'w', driver='GTiff', height=full_raster.shape[0],
                       width=full_raster.shape[1], count=1, dtype=full_raster.dtype) as dst:
        dst.write(full_raster, 1)

def create_tfw_file(transform, tfw_path):
    print(f"Creating .tfw file at {tfw_path}")
    with open(tfw_path, 'w') as f:
        f.write(f"{transform.a}\n")  # pixel size in the x-direction
        f.write(f"{transform.b}\n")  # rotation term (always 0 for north-up images)
        f.write(f"{transform.d}\n")  # rotation term (always 0 for north-up images)
        f.write(f"{transform.e}\n")  # pixel size in the y-direction (usually negative)
        f.write(f"{transform.c}\n")  # x-coordinate of the upper-left corner of the upper-left pixel
        f.write(f"{transform.f}\n")  # y-coordinate of the upper-left corner of the upper-left pixel

if __name__ == "__main__":
    image_path = f'data/{filename_to_detect}.tif'
    tile_size = 96
    batch_size = 12
    model = initialize_model()

    print("Loading and preprocessing the large image")
    large_image, transform = load_large_image(image_path)
    large_image = NumpyDataset.replace_nans_in_array(large_image)
    image_shape = large_image.shape
    print(f"Large image shape: {image_shape}")

    temp_dir = './model/temp/'
    npy_dir = './model/temp_npy/'
    pred_dir = './model/temp_pred/'
    result_path = f'./model/Swin_UNETR/Aug/{filename_to_detect}_swinunetr.tif'
    tfw_path = f'./model/Swin_UNETR/Aug/{filename_to_detect}_swinunetr.tfw'

    if not os.path.exists(temp_dir):
        os.makedirs(temp_dir)

    tile_paths = split_to_tiles(large_image, tile_size, temp_dir)
    npy_paths = convert_tiles_to_npy(tile_paths, npy_dir)
    test_loader = prepare_test_loader(npy_paths, batch_size)

    adapted_model_path = 'model/Swin_UNETR/Aug/bin_best_model_lr_B.pth'
    model = load_adapted_model(model, adapted_model_path)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    predictions = predict_and_save(model, test_loader, device, tile_paths, save_dir=pred_dir)

    # Adjust the image_shape to reflect the single-channel output
    single_channel_image_shape = (1, image_shape[1], image_shape[2])
    save_full_raster(predictions, single_channel_image_shape, tile_size, result_path)

    # Create the .tfw file using the transform from the original large image
    create_tfw_file(transform, tfw_path)

    print("Prediction, saving, and .tfw file creation complete")
# Out:
# Enter the path to the image:  Swin_UNETR_N48XL/data/M1_selected_L5_S2_S1_MSRM_PCA_N48-0000000000-0000000000.tif
# Loading and preprocessing the large image
# Loading large image from data/M1_selected_L5_S2_S1_MSRM_PCA_N48-0000000000-0000000000.tif
# Large image shape: (48, 4864, 3456)
# Splitting image into tiles of size 96x96
# Saving tile to ./model/temp/tile_0_0.tif
# Saving tile to ./model/temp/tile_0_96.tif
# Saving tile to ./model/temp/tile_0_192.tif
# Saving tile to ./model/temp/tile_0_288.tif
# Saving tile to ./model/temp/tile_0_384.tif
# Saving tile to ./model/temp/tile_0_480.tif
# Saving tile to ./model/temp/tile_0_576.tif
# Saving tile to ./model/temp/tile_0_672.tif
# Saving tile to ./model/temp/tile_0_768.tif
# Saving tile to ./model/temp/tile_0_864.tif
# Saving tile to ./model/temp/tile_0_960.tif
# Saving tile to ./model/temp/tile_0_1056.tif
# Saving tile to ./model/temp/tile_0_1152.tif
# Saving tile to ./model/temp/tile_0_1248.tif
# Saving tile to ./model/temp/tile_0_1344.tif
# Saving tile to ./model/temp/tile_0_1440.tif
# Saving tile to ./model/temp/tile_0_1536.tif
# Saving tile to ./model/temp/tile_0_1632.tif
# Saving tile to ./model/temp/tile_0_1728.tif
# Saving tile to ./model/temp/tile_0_1824.tif
# Saving tile to ./model/temp/tile_0_1920.tif
# Saving tile to ./model/temp/tile_0_2016.tif
# Saving tile to ./model/temp/tile_0_2112.tif
# Saving tile to ./model/temp/tile_0_2208.tif
# Saving tile to ./model/temp/tile_0_2304.tif
# Saving tile to ./model/temp/tile_0_2400.tif
# Saving tile to ./model/temp/tile_0_2496.tif
# Saving tile to ./model/temp/tile_0_2592.tif
# Saving tile to ./model/temp/tile_0_2688.tif
# Saving tile to ./model/temp/tile_0_2784.tif
# Saving tile to ./model/temp/tile_0_2880.tif
# Saving tile to ./model/temp/tile_0_2976.tif
# Saving tile to ./model/temp/tile_0_3072.tif
# Saving tile to ./model/temp/tile_0_3168.tif
# Saving tile to ./model/temp/tile_0_3264.tif
# Saving tile to ./model/temp/tile_0_3360.tif
# Saving tile to ./model/temp/tile_96_0.tif
# Saving tile to ./model/temp/tile_96_96.tif
# Saving tile to ./model/temp/tile_96_192.tif
# Saving tile to ./model/temp/tile_96_288.tif
# Saving tile to ./model/temp/tile_96_384.tif
# Saving tile to ./model/temp/tile_96_480.tif
# Saving tile to ./model/temp/tile_96_576.tif
# Saving tile to ./model/temp/tile_96_672.tif
# Saving tile to ./model/temp/tile_96_768.tif
# Saving tile to ./model/temp/tile_96_864.tif
# Saving tile to ./model/temp/tile_96_960.tif
# Saving tile to ./model/temp/tile_96_1056.tif
# Saving tile to ./model/temp/tile_96_1152.tif
# Saving tile to ./model/temp/tile_96_1248.tif
# Saving tile to ./model/temp/tile_96_1344.tif
# Saving tile to ./model/temp/tile_96_1440.tif
# Saving tile to ./model/temp/tile_96_1536.tif
# Saving tile to ./model/temp/tile_96_1632.tif
# Saving tile to ./model/temp/tile_96_1728.tif
# Saving tile to ./model/temp/tile_96_1824.tif
# Saving tile to ./model/temp/tile_96_1920.tif
# Saving tile to ./model/temp/tile_96_2016.tif
# Saving tile to ./model/temp/tile_96_2112.tif
# Saving tile to ./model/temp/tile_96_2208.tif
# Saving tile to ./model/temp/tile_96_2304.tif
# Saving tile to ./model/temp/tile_96_2400.tif
# Saving tile to ./model/temp/tile_96_2496.tif
# Saving tile to ./model/temp/tile_96_2592.tif
# Saving tile to ./model/temp/tile_96_2688.tif
# Saving tile to ./model/temp/tile_96_2784.tif
# Saving tile to ./model/temp/tile_96_2880.tif
# Saving tile to ./model/temp/tile_96_2976.tif
# Saving tile to ./model/temp/tile_96_3072.tif
# Saving tile to ./model/temp/tile_96_3168.tif
# Saving tile to ./model/temp/tile_96_3264.tif
# Saving tile to ./model/temp/tile_96_3360.tif
# Saving tile to ./model/temp/tile_192_0.tif
# Saving tile to ./model/temp/tile_192_96.tif
# Saving tile to ./model/temp/tile_192_192.tif
# Saving tile to ./model/temp/tile_192_288.tif
# Saving tile to ./model/temp/tile_192_384.tif
# Saving tile to ./model/temp/tile_192_480.tif
# Saving tile to ./model/temp/tile_192_576.tif
# Saving tile to ./model/temp/tile_192_672.tif
# Saving tile to ./model/temp/tile_192_768.tif
# Saving tile to ./model/temp/tile_192_864.tif
# Saving tile to ./model/temp/tile_192_960.tif
# Saving tile to ./model/temp/tile_192_1056.tif
# Saving tile to ./model/temp/tile_192_1152.tif
# Saving tile to ./model/temp/tile_192_1248.tif
# Saving tile to ./model/temp/tile_192_1344.tif
# Saving tile to ./model/temp/tile_192_1440.tif
# Saving tile to ./model/temp/tile_192_1536.tif
# Saving tile to ./model/temp/tile_192_1632.tif
# Saving tile to ./model/temp/tile_192_1728.tif
# Saving tile to ./model/temp/tile_192_1824.tif
# Saving tile to ./model/temp/tile_192_1920.tif
# Saving tile to ./model/temp/tile_192_2016.tif
# Saving tile to ./model/temp/tile_192_2112.tif
# Saving tile to ./model/temp/tile_192_2208.tif
# Saving tile to ./model/temp/tile_192_2304.tif
# Saving tile to ./model/temp/tile_192_2400.tif
# Saving tile to ./model/temp/tile_192_2496.tif
# Saving tile to ./model/temp/tile_192_2592.tif
# Saving tile to ./model/temp/tile_192_2688.tif
# Saving tile to ./model/temp/tile_192_2784.tif
# Saving tile to ./model/temp/tile_192_2880.tif
# Saving tile to ./model/temp/tile_192_2976.tif
# Saving tile to ./model/temp/tile_192_3072.tif
# Saving tile to ./model/temp/tile_192_3168.tif
# Saving tile to ./model/temp/tile_192_3264.tif
# Saving tile to ./model/temp/tile_192_3360.tif
# Saving tile to ./model/temp/tile_288_0.tif
# Saving tile to ./model/temp/tile_288_96.tif
# Saving tile to ./model/temp/tile_288_192.tif
# Saving tile to ./model/temp/tile_288_288.tif
# Saving tile to ./model/temp/tile_288_384.tif
# Saving tile to ./model/temp/tile_288_480.tif
# Saving tile to ./model/temp/tile_288_576.tif
# Saving tile to ./model/temp/tile_288_672.tif
# Saving tile to ./model/temp/tile_288_768.tif
# Saving tile to ./model/temp/tile_288_864.tif
# Saving tile to ./model/temp/tile_288_960.tif
# Saving tile to ./model/temp/tile_288_1056.tif
# Saving tile to ./model/temp/tile_288_1152.tif
# Saving tile to ./model/temp/tile_288_1248.tif
# Saving tile to ./model/temp/tile_288_1344.tif
# Saving tile to ./model/temp/tile_288_1440.tif
# Saving tile to ./model/temp/tile_288_1536.tif
# Saving tile to ./model/temp/tile_288_1632.tif
# Saving tile to ./model/temp/tile_288_1728.tif
# Saving tile to ./model/temp/tile_288_1824.tif
# Saving tile to ./model/temp/tile_288_1920.tif
# Saving tile to ./model/temp/tile_288_2016.tif
# Saving tile to ./model/temp/tile_288_2112.tif
# Saving tile to ./model/temp/tile_288_2208.tif
# Saving tile to ./model/temp/tile_288_2304.tif
# Saving tile to ./model/temp/tile_288_2400.tif
# Saving tile to ./model/temp/tile_288_2496.tif
# Saving tile to ./model/temp/tile_288_2592.tif
# Saving tile to ./model/temp/tile_288_2688.tif
# Saving tile to ./model/temp/tile_288_2784.tif
# Saving tile to ./model/temp/tile_288_2880.tif
# Saving tile to ./model/temp/tile_288_2976.tif
# Saving tile to ./model/temp/tile_288_3072.tif
# Saving tile to ./model/temp/tile_288_3168.tif
# Saving tile to ./model/temp/tile_288_3264.tif
# Saving tile to ./model/temp/tile_288_3360.tif
# Saving tile to ./model/temp/tile_384_0.tif
# Saving tile to ./model/temp/tile_384_96.tif
# Saving tile to ./model/temp/tile_384_192.tif
# Saving tile to ./model/temp/tile_384_288.tif
# Saving tile to ./model/temp/tile_384_384.tif
# Saving tile to ./model/temp/tile_384_480.tif
# Saving tile to ./model/temp/tile_384_576.tif
# Saving tile to ./model/temp/tile_384_672.tif
# Saving tile to ./model/temp/tile_384_768.tif
# Saving tile to ./model/temp/tile_384_864.tif
# Saving tile to ./model/temp/tile_384_960.tif
# Saving tile to ./model/temp/tile_384_1056.tif
# Saving tile to ./model/temp/tile_384_1152.tif
# Saving tile to ./model/temp/tile_384_1248.tif
# Saving tile to ./model/temp/tile_384_1344.tif
# Saving tile to ./model/temp/tile_384_1440.tif
# Saving tile to ./model/temp/tile_384_1536.tif
# Saving tile to ./model/temp/tile_384_1632.tif
# Saving tile to ./model/temp/tile_384_1728.tif
# Saving tile to ./model/temp/tile_384_1824.tif
# Saving tile to ./model/temp/tile_384_1920.tif
# Saving tile to ./model/temp/tile_384_2016.tif
# Saving tile to ./model/temp/tile_384_2112.tif
# Saving tile to ./model/temp/tile_384_2208.tif
# Saving tile to ./model/temp/tile_384_2304.tif
# Saving tile to ./model/temp/tile_384_2400.tif
# Saving tile to ./model/temp/tile_384_2496.tif
# Saving tile to ./model/temp/tile_384_2592.tif
# Saving tile to ./model/temp/tile_384_2688.tif
# Saving tile to ./model/temp/tile_384_2784.tif
# Saving tile to ./model/temp/tile_384_2880.tif
# Saving tile to ./model/temp/tile_384_2976.tif
# Saving tile to ./model/temp/tile_384_3072.tif
# Saving tile to ./model/temp/tile_384_3168.tif
# Saving tile to ./model/temp/tile_384_3264.tif
# Saving tile to ./model/temp/tile_384_3360.tif
# Saving tile to ./model/temp/tile_480_0.tif
# Saving tile to ./model/temp/tile_480_96.tif
# Saving tile to ./model/temp/tile_480_192.tif
# Saving tile to ./model/temp/tile_480_288.tif
# Saving tile to ./model/temp/tile_480_384.tif
# Saving tile to ./model/temp/tile_480_480.tif
# Saving tile to ./model/temp/tile_480_576.tif
# Saving tile to ./model/temp/tile_480_672.tif
# Saving tile to ./model/temp/tile_480_768.tif
# Saving tile to ./model/temp/tile_480_864.tif
# Saving tile to ./model/temp/tile_480_960.tif
# Saving tile to ./model/temp/tile_480_1056.tif
# Saving tile to ./model/temp/tile_480_1152.tif
# Saving tile to ./model/temp/tile_480_1248.tif
# Saving tile to ./model/temp/tile_480_1344.tif
# Saving tile to ./model/temp/tile_480_1440.tif
# Saving tile to ./model/temp/tile_480_1536.tif
# Saving tile to ./model/temp/tile_480_1632.tif
# Saving tile to ./model/temp/tile_480_1728.tif
# Saving tile to ./model/temp/tile_480_1824.tif
# Saving tile to ./model/temp/tile_480_1920.tif
# Saving tile to ./model/temp/tile_480_2016.tif
# Saving tile to ./model/temp/tile_480_2112.tif
# Saving tile to ./model/temp/tile_480_2208.tif
# Saving tile to ./model/temp/tile_480_2304.tif
# Saving tile to ./model/temp/tile_480_2400.tif
# Saving tile to ./model/temp/tile_480_2496.tif
# Saving tile to ./model/temp/tile_480_2592.tif
# Saving tile to ./model/temp/tile_480_2688.tif
# Saving tile to ./model/temp/tile_480_2784.tif
# Saving tile to ./model/temp/tile_480_2880.tif
# Saving tile to ./model/temp/tile_480_2976.tif
# Saving tile to ./model/temp/tile_480_3072.tif
# Saving tile to ./model/temp/tile_480_3168.tif
# Saving tile to ./model/temp/tile_480_3264.tif
# Saving tile to ./model/temp/tile_480_3360.tif
# Saving tile to ./model/temp/tile_576_0.tif
# Saving tile to ./model/temp/tile_576_96.tif
# Saving tile to ./model/temp/tile_576_192.tif
# Saving tile to ./model/temp/tile_576_288.tif
# Saving tile to ./model/temp/tile_576_384.tif
# Saving tile to ./model/temp/tile_576_480.tif
# Saving tile to ./model/temp/tile_576_576.tif
# Saving tile to ./model/temp/tile_576_672.tif
# Saving tile to ./model/temp/tile_576_768.tif
# Saving tile to ./model/temp/tile_576_864.tif
# Saving tile to ./model/temp/tile_576_960.tif
# Saving tile to ./model/temp/tile_576_1056.tif
# Saving tile to ./model/temp/tile_576_1152.tif
# Saving tile to ./model/temp/tile_576_1248.tif
# Saving tile to ./model/temp/tile_576_1344.tif
# Saving tile to ./model/temp/tile_576_1440.tif
# Saving tile to ./model/temp/tile_576_1536.tif
# Saving tile to ./model/temp/tile_576_1632.tif
# Saving tile to ./model/temp/tile_576_1728.tif
# Saving tile to ./model/temp/tile_576_1824.tif
# Saving tile to ./model/temp/tile_576_1920.tif
# Saving tile to ./model/temp/tile_576_2016.tif
# Saving tile to ./model/temp/tile_576_2112.tif
# Saving tile to ./model/temp/tile_576_2208.tif
# Saving tile to ./model/temp/tile_576_2304.tif
# Saving tile to ./model/temp/tile_576_2400.tif
# Saving tile to ./model/temp/tile_576_2496.tif
# Saving tile to ./model/temp/tile_576_2592.tif
# Saving tile to ./model/temp/tile_576_2688.tif
# Saving tile to ./model/temp/tile_576_2784.tif
# Saving tile to ./model/temp/tile_576_2880.tif
# Saving tile to ./model/temp/tile_576_2976.tif
# Saving tile to ./model/temp/tile_576_3072.tif
# Saving tile to ./model/temp/tile_576_3168.tif
# Saving tile to ./model/temp/tile_576_3264.tif
# Saving tile to ./model/temp/tile_576_3360.tif
# Saving tile to ./model/temp/tile_672_0.tif
# Saving tile to ./model/temp/tile_672_96.tif
# Saving tile to ./model/temp/tile_672_192.tif
# Saving tile to ./model/temp/tile_672_288.tif
# Saving tile to ./model/temp/tile_672_384.tif
# Saving tile to ./model/temp/tile_672_480.tif
# Saving tile to ./model/temp/tile_672_576.tif
# Saving tile to ./model/temp/tile_672_672.tif
# Saving tile to ./model/temp/tile_672_768.tif
# Saving tile to ./model/temp/tile_672_864.tif
# Saving tile to ./model/temp/tile_672_960.tif
# Saving tile to ./model/temp/tile_672_1056.tif
# Saving tile to ./model/temp/tile_672_1152.tif
# Saving tile to ./model/temp/tile_672_1248.tif
# Saving tile to ./model/temp/tile_672_1344.tif
# Saving tile to ./model/temp/tile_672_1440.tif
# Saving tile to ./model/temp/tile_672_1536.tif
# Saving tile to ./model/temp/tile_672_1632.tif
# Saving tile to ./model/temp/tile_672_1728.tif
# Saving tile to ./model/temp/tile_672_1824.tif
# Saving tile to ./model/temp/tile_672_1920.tif
# Saving tile to ./model/temp/tile_672_2016.tif
# Saving tile to ./model/temp/tile_672_2112.tif
# Saving tile to ./model/temp/tile_672_2208.tif
# Saving tile to ./model/temp/tile_672_2304.tif
# Saving tile to ./model/temp/tile_672_2400.tif
# Saving tile to ./model/temp/tile_672_2496.tif
# Saving tile to ./model/temp/tile_672_2592.tif
# Saving tile to ./model/temp/tile_672_2688.tif
# Saving tile to ./model/temp/tile_672_2784.tif
# Saving tile to ./model/temp/tile_672_2880.tif
# Saving tile to ./model/temp/tile_672_2976.tif
# Saving tile to ./model/temp/tile_672_3072.tif
# Saving tile to ./model/temp/tile_672_3168.tif
# Saving tile to ./model/temp/tile_672_3264.tif
# Saving tile to ./model/temp/tile_672_3360.tif
# Saving tile to ./model/temp/tile_768_0.tif
# Saving tile to ./model/temp/tile_768_96.tif
# Saving tile to ./model/temp/tile_768_192.tif
# Saving tile to ./model/temp/tile_768_288.tif
# Saving tile to ./model/temp/tile_768_384.tif
# Saving tile to ./model/temp/tile_768_480.tif
# Saving tile to ./model/temp/tile_768_576.tif
# Saving tile to ./model/temp/tile_768_672.tif
# Saving tile to ./model/temp/tile_768_768.tif
# Saving tile to ./model/temp/tile_768_864.tif
# Saving tile to ./model/temp/tile_768_960.tif
# Saving tile to ./model/temp/tile_768_1056.tif
# Saving tile to ./model/temp/tile_768_1152.tif
# Saving tile to ./model/temp/tile_768_1248.tif
# Saving tile to ./model/temp/tile_768_1344.tif
# Saving tile to ./model/temp/tile_768_1440.tif
# Saving tile to ./model/temp/tile_768_1536.tif
# Saving tile to ./model/temp/tile_768_1632.tif
# Saving tile to ./model/temp/tile_768_1728.tif
# Saving tile to ./model/temp/tile_768_1824.tif
# Saving tile to ./model/temp/tile_768_1920.tif
# Saving tile to ./model/temp/tile_768_2016.tif
# Saving tile to ./model/temp/tile_768_2112.tif
# Saving tile to ./model/temp/tile_768_2208.tif
# Saving tile to ./model/temp/tile_768_2304.tif
# Saving tile to ./model/temp/tile_768_2400.tif
# Saving tile to ./model/temp/tile_768_2496.tif
# Saving tile to ./model/temp/tile_768_2592.tif
# Saving tile to ./model/temp/tile_768_2688.tif
# Saving tile to ./model/temp/tile_768_2784.tif
# Saving tile to ./model/temp/tile_768_2880.tif
# Saving tile to ./model/temp/tile_768_2976.tif
# Saving tile to ./model/temp/tile_768_3072.tif
# Saving tile to ./model/temp/tile_768_3168.tif
# Saving tile to ./model/temp/tile_768_3264.tif
# Saving tile to ./model/temp/tile_768_3360.tif
# Saving tile to ./model/temp/tile_864_0.tif
# Saving tile to ./model/temp/tile_864_96.tif
# Saving tile to ./model/temp/tile_864_192.tif
# Saving tile to ./model/temp/tile_864_288.tif
# Saving tile to ./model/temp/tile_864_384.tif
# Saving tile to ./model/temp/tile_864_480.tif
# Saving tile to ./model/temp/tile_864_576.tif
# Saving tile to ./model/temp/tile_864_672.tif
# Saving tile to ./model/temp/tile_864_768.tif
# Saving tile to ./model/temp/tile_864_864.tif
# Saving tile to ./model/temp/tile_864_960.tif
# Saving tile to ./model/temp/tile_864_1056.tif
# Saving tile to ./model/temp/tile_864_1152.tif
# Saving tile to ./model/temp/tile_864_1248.tif
# Saving tile to ./model/temp/tile_864_1344.tif
# Saving tile to ./model/temp/tile_864_1440.tif
# Saving tile to ./model/temp/tile_864_1536.tif
# Saving tile to ./model/temp/tile_864_1632.tif
# Saving tile to ./model/temp/tile_864_1728.tif
# Saving tile to ./model/temp/tile_864_1824.tif
# Saving tile to ./model/temp/tile_864_1920.tif
# Saving tile to ./model/temp/tile_864_2016.tif
# Saving tile to ./model/temp/tile_864_2112.tif
# Saving tile to ./model/temp/tile_864_2208.tif
# Saving tile to ./model/temp/tile_864_2304.tif
# Saving tile to ./model/temp/tile_864_2400.tif
# Saving tile to ./model/temp/tile_864_2496.tif
# Saving tile to ./model/temp/tile_864_2592.tif
# Saving tile to ./model/temp/tile_864_2688.tif
# Saving tile to ./model/temp/tile_864_2784.tif
# Saving tile to ./model/temp/tile_864_2880.tif
# Saving tile to ./model/temp/tile_864_2976.tif
# Saving tile to ./model/temp/tile_864_3072.tif
# Saving tile to ./model/temp/tile_864_3168.tif
# Saving tile to ./model/temp/tile_864_3264.tif
# Saving tile to ./model/temp/tile_864_3360.tif
# Saving tile to ./model/temp/tile_960_0.tif
# Saving tile to ./model/temp/tile_960_96.tif
# Saving tile to ./model/temp/tile_960_192.tif
# Saving tile to ./model/temp/tile_960_288.tif
# Saving tile to ./model/temp/tile_960_384.tif
# Saving tile to ./model/temp/tile_960_480.tif
# Saving tile to ./model/temp/tile_960_576.tif
# Saving tile to ./model/temp/tile_960_672.tif
# Saving tile to ./model/temp/tile_960_768.tif
# Saving tile to ./model/temp/tile_960_864.tif
# Saving tile to ./model/temp/tile_960_960.tif
# Saving tile to ./model/temp/tile_960_1056.tif
# Saving tile to ./model/temp/tile_960_1152.tif
# Saving tile to ./model/temp/tile_960_1248.tif
# Saving tile to ./model/temp/tile_960_1344.tif
# Saving tile to ./model/temp/tile_960_1440.tif
# Saving tile to ./model/temp/tile_960_1536.tif
# Saving tile to ./model/temp/tile_960_1632.tif
# Saving tile to ./model/temp/tile_960_1728.tif
# Saving tile to ./model/temp/tile_960_1824.tif
# Saving tile to ./model/temp/tile_960_1920.tif
# Saving tile to ./model/temp/tile_960_2016.tif
# Saving tile to ./model/temp/tile_960_2112.tif
# Saving tile to ./model/temp/tile_960_2208.tif
# Saving tile to ./model/temp/tile_960_2304.tif
# Saving tile to ./model/temp/tile_960_2400.tif
# Saving tile to ./model/temp/tile_960_2496.tif
# Saving tile to ./model/temp/tile_960_2592.tif
# Saving tile to ./model/temp/tile_960_2688.tif
# Saving tile to ./model/temp/tile_960_2784.tif
# Saving tile to ./model/temp/tile_960_2880.tif
# Saving tile to ./model/temp/tile_960_2976.tif
# Saving tile to ./model/temp/tile_960_3072.tif
# Saving tile to ./model/temp/tile_960_3168.tif
# Saving tile to ./model/temp/tile_960_3264.tif
# Saving tile to ./model/temp/tile_960_3360.tif
# Saving tile to ./model/temp/tile_1056_0.tif
# Saving tile to ./model/temp/tile_1056_96.tif
# Saving tile to ./model/temp/tile_1056_192.tif
# Saving tile to ./model/temp/tile_1056_288.tif
# Saving tile to ./model/temp/tile_1056_384.tif
# Saving tile to ./model/temp/tile_1056_480.tif
# Saving tile to ./model/temp/tile_1056_576.tif
# Saving tile to ./model/temp/tile_1056_672.tif
# Saving tile to ./model/temp/tile_1056_768.tif
# Saving tile to ./model/temp/tile_1056_864.tif
# Saving tile to ./model/temp/tile_1056_960.tif
# Saving tile to ./model/temp/tile_1056_1056.tif
# Saving tile to ./model/temp/tile_1056_1152.tif
# Saving tile to ./model/temp/tile_1056_1248.tif
# Saving tile to ./model/temp/tile_1056_1344.tif
# Saving tile to ./model/temp/tile_1056_1440.tif
# Saving tile to ./model/temp/tile_1056_1536.tif
# Saving tile to ./model/temp/tile_1056_1632.tif
# Saving tile to ./model/temp/tile_1056_1728.tif
# Saving tile to ./model/temp/tile_1056_1824.tif
# Saving tile to ./model/temp/tile_1056_1920.tif
# Saving tile to ./model/temp/tile_1056_2016.tif
# Saving tile to ./model/temp/tile_1056_2112.tif
# Saving tile to ./model/temp/tile_1056_2208.tif
# Saving tile to ./model/temp/tile_1056_2304.tif
# Saving tile to ./model/temp/tile_1056_2400.tif
# Saving tile to ./model/temp/tile_1056_2496.tif
# Saving tile to ./model/temp/tile_1056_2592.tif
# Saving tile to ./model/temp/tile_1056_2688.tif
# Saving tile to ./model/temp/tile_1056_2784.tif
# Saving tile to ./model/temp/tile_1056_2880.tif
# Saving tile to ./model/temp/tile_1056_2976.tif
# Saving tile to ./model/temp/tile_1056_3072.tif
# Saving tile to ./model/temp/tile_1056_3168.tif
# Saving tile to ./model/temp/tile_1056_3264.tif
# Saving tile to ./model/temp/tile_1056_3360.tif
# Saving tile to ./model/temp/tile_1152_0.tif
# Saving tile to ./model/temp/tile_1152_96.tif
# Saving tile to ./model/temp/tile_1152_192.tif
# Saving tile to ./model/temp/tile_1152_288.tif
# Saving tile to ./model/temp/tile_1152_384.tif
# Saving tile to ./model/temp/tile_1152_480.tif
# Saving tile to ./model/temp/tile_1152_576.tif
# Saving tile to ./model/temp/tile_1152_672.tif
# Saving tile to ./model/temp/tile_1152_768.tif
# Saving tile to ./model/temp/tile_1152_864.tif
# Saving tile to ./model/temp/tile_1152_960.tif
# Saving tile to ./model/temp/tile_1152_1056.tif
# Saving tile to ./model/temp/tile_1152_1152.tif
# Saving tile to ./model/temp/tile_1152_1248.tif
# Saving tile to ./model/temp/tile_1152_1344.tif
# Saving tile to ./model/temp/tile_1152_1440.tif
# Saving tile to ./model/temp/tile_1152_1536.tif
# Saving tile to ./model/temp/tile_1152_1632.tif
# Saving tile to ./model/temp/tile_1152_1728.tif
# Saving tile to ./model/temp/tile_1152_1824.tif
# Saving tile to ./model/temp/tile_1152_1920.tif
# Saving tile to ./model/temp/tile_1152_2016.tif
# Saving tile to ./model/temp/tile_1152_2112.tif
# Saving tile to ./model/temp/tile_1152_2208.tif
# Saving tile to ./model/temp/tile_1152_2304.tif
# Saving tile to ./model/temp/tile_1152_2400.tif
# Saving tile to ./model/temp/tile_1152_2496.tif
# Saving tile to ./model/temp/tile_1152_2592.tif
# Saving tile to ./model/temp/tile_1152_2688.tif
# Saving tile to ./model/temp/tile_1152_2784.tif
# Saving tile to ./model/temp/tile_1152_2880.tif
# Saving tile to ./model/temp/tile_1152_2976.tif
# Saving tile to ./model/temp/tile_1152_3072.tif
# Saving tile to ./model/temp/tile_1152_3168.tif
# Saving tile to ./model/temp/tile_1152_3264.tif
# Saving tile to ./model/temp/tile_1152_3360.tif
# Saving tile to ./model/temp/tile_1248_0.tif
# Saving tile to ./model/temp/tile_1248_96.tif
# Saving tile to ./model/temp/tile_1248_192.tif
# Saving tile to ./model/temp/tile_1248_288.tif
# Saving tile to ./model/temp/tile_1248_384.tif
# Saving tile to ./model/temp/tile_1248_480.tif
# Saving tile to ./model/temp/tile_1248_576.tif
# Saving tile to ./model/temp/tile_1248_672.tif
# Saving tile to ./model/temp/tile_1248_768.tif
# Saving tile to ./model/temp/tile_1248_864.tif
# Saving tile to ./model/temp/tile_1248_960.tif
# Saving tile to ./model/temp/tile_1248_1056.tif
# Saving tile to ./model/temp/tile_1248_1152.tif
# Saving tile to ./model/temp/tile_1248_1248.tif
# Saving tile to ./model/temp/tile_1248_1344.tif
# Saving tile to ./model/temp/tile_1248_1440.tif
# Saving tile to ./model/temp/tile_1248_1536.tif
# Saving tile to ./model/temp/tile_1248_1632.tif
# Saving tile to ./model/temp/tile_1248_1728.tif
# Saving tile to ./model/temp/tile_1248_1824.tif
# Saving tile to ./model/temp/tile_1248_1920.tif
# Saving tile to ./model/temp/tile_1248_2016.tif
# Saving tile to ./model/temp/tile_1248_2112.tif
# Saving tile to ./model/temp/tile_1248_2208.tif
# Saving tile to ./model/temp/tile_1248_2304.tif
# Saving tile to ./model/temp/tile_1248_2400.tif
# Saving tile to ./model/temp/tile_1248_2496.tif
# Saving tile to ./model/temp/tile_1248_2592.tif
# Saving tile to ./model/temp/tile_1248_2688.tif
# Saving tile to ./model/temp/tile_1248_2784.tif
# Saving tile to ./model/temp/tile_1248_2880.tif
# Saving tile to ./model/temp/tile_1248_2976.tif
# Saving tile to ./model/temp/tile_1248_3072.tif
# Saving tile to ./model/temp/tile_1248_3168.tif
# Saving tile to ./model/temp/tile_1248_3264.tif
# Saving tile to ./model/temp/tile_1248_3360.tif
# Saving tile to ./model/temp/tile_1344_0.tif
# Saving tile to ./model/temp/tile_1344_96.tif
# Saving tile to ./model/temp/tile_1344_192.tif
# Saving tile to ./model/temp/tile_1344_288.tif
# Saving tile to ./model/temp/tile_1344_384.tif
# Saving tile to ./model/temp/tile_1344_480.tif
# Saving tile to ./model/temp/tile_1344_576.tif
# Saving tile to ./model/temp/tile_1344_672.tif
# Saving tile to ./model/temp/tile_1344_768.tif
# Saving tile to ./model/temp/tile_1344_864.tif
# Saving tile to ./model/temp/tile_1344_960.tif
# Saving tile to ./model/temp/tile_1344_1056.tif
# Saving tile to ./model/temp/tile_1344_1152.tif
# Saving tile to ./model/temp/tile_1344_1248.tif
# Saving tile to ./model/temp/tile_1344_1344.tif
# Saving tile to ./model/temp/tile_1344_1440.tif
# Saving tile to ./model/temp/tile_1344_1536.tif
# Saving tile to ./model/temp/tile_1344_1632.tif
# Saving tile to ./model/temp/tile_1344_1728.tif
# Saving tile to ./model/temp/tile_1344_1824.tif
# Saving tile to ./model/temp/tile_1344_1920.tif
# Saving tile to ./model/temp/tile_1344_2016.tif
# Saving tile to ./model/temp/tile_1344_2112.tif
# Saving tile to ./model/temp/tile_1344_2208.tif
# Saving tile to ./model/temp/tile_1344_2304.tif
# Saving tile to ./model/temp/tile_1344_2400.tif
# Saving tile to ./model/temp/tile_1344_2496.tif
# Saving tile to ./model/temp/tile_1344_2592.tif
# Saving tile to ./model/temp/tile_1344_2688.tif
# Saving tile to ./model/temp/tile_1344_2784.tif
# Saving tile to ./model/temp/tile_1344_2880.tif
# Saving tile to ./model/temp/tile_1344_2976.tif
# Saving tile to ./model/temp/tile_1344_3072.tif
# Saving tile to ./model/temp/tile_1344_3168.tif
# Saving tile to ./model/temp/tile_1344_3264.tif
# Saving tile to ./model/temp/tile_1344_3360.tif
# Saving tile to ./model/temp/tile_1440_0.tif
# Saving tile to ./model/temp/tile_1440_96.tif
# Saving tile to ./model/temp/tile_1440_192.tif
# Saving tile to ./model/temp/tile_1440_288.tif
# Saving tile to ./model/temp/tile_1440_384.tif
# Saving tile to ./model/temp/tile_1440_480.tif
# Saving tile to ./model/temp/tile_1440_576.tif
# Saving tile to ./model/temp/tile_1440_672.tif
# Saving tile to ./model/temp/tile_1440_768.tif
# Saving tile to ./model/temp/tile_1440_864.tif
# Saving tile to ./model/temp/tile_1440_960.tif
# Saving tile to ./model/temp/tile_1440_1056.tif
# Saving tile to ./model/temp/tile_1440_1152.tif
# Saving tile to ./model/temp/tile_1440_1248.tif
# Saving tile to ./model/temp/tile_1440_1344.tif
# Saving tile to ./model/temp/tile_1440_1440.tif
# Saving tile to ./model/temp/tile_1440_1536.tif
# Saving tile to ./model/temp/tile_1440_1632.tif
# Saving tile to ./model/temp/tile_1440_1728.tif
# Saving tile to ./model/temp/tile_1440_1824.tif
# Saving tile to ./model/temp/tile_1440_1920.tif
# Saving tile to ./model/temp/tile_1440_2016.tif
# Saving tile to ./model/temp/tile_1440_2112.tif
# Saving tile to ./model/temp/tile_1440_2208.tif
# Saving tile to ./model/temp/tile_1440_2304.tif
# Saving tile to ./model/temp/tile_1440_2400.tif
# Saving tile to ./model/temp/tile_1440_2496.tif
# Saving tile to ./model/temp/tile_1440_2592.tif
# Saving tile to ./model/temp/tile_1440_2688.tif
# Saving tile to ./model/temp/tile_1440_2784.tif
# Saving tile to ./model/temp/tile_1440_2880.tif
# Saving tile to ./model/temp/tile_1440_2976.tif
# Saving tile to ./model/temp/tile_1440_3072.tif
# Saving tile to ./model/temp/tile_1440_3168.tif
# Saving tile to ./model/temp/tile_1440_3264.tif
# Saving tile to ./model/temp/tile_1440_3360.tif
# Saving tile to ./model/temp/tile_1536_0.tif
# Saving tile to ./model/temp/tile_1536_96.tif
# Saving tile to ./model/temp/tile_1536_192.tif
# Saving tile to ./model/temp/tile_1536_288.tif
# Saving tile to ./model/temp/tile_1536_384.tif
# Saving tile to ./model/temp/tile_1536_480.tif
# Saving tile to ./model/temp/tile_1536_576.tif
# Saving tile to ./model/temp/tile_1536_672.tif
# Saving tile to ./model/temp/tile_1536_768.tif
# Saving tile to ./model/temp/tile_1536_864.tif
# Saving tile to ./model/temp/tile_1536_960.tif
# Saving tile to ./model/temp/tile_1536_1056.tif
# Saving tile to ./model/temp/tile_1536_1152.tif
# Saving tile to ./model/temp/tile_1536_1248.tif
# Saving tile to ./model/temp/tile_1536_1344.tif
# Saving tile to ./model/temp/tile_1536_1440.tif
# Saving tile to ./model/temp/tile_1536_1536.tif
# Saving tile to ./model/temp/tile_1536_1632.tif
# Saving tile to ./model/temp/tile_1536_1728.tif
# Saving tile to ./model/temp/tile_1536_1824.tif
# Saving tile to ./model/temp/tile_1536_1920.tif
# Saving tile to ./model/temp/tile_1536_2016.tif
# Saving tile to ./model/temp/tile_1536_2112.tif
# Saving tile to ./model/temp/tile_1536_2208.tif
# Saving tile to ./model/temp/tile_1536_2304.tif
# Saving tile to ./model/temp/tile_1536_2400.tif
# Saving tile to ./model/temp/tile_1536_2496.tif
# Saving tile to ./model/temp/tile_1536_2592.tif
# Saving tile to ./model/temp/tile_1536_2688.tif
# Saving tile to ./model/temp/tile_1536_2784.tif
# Saving tile to ./model/temp/tile_1536_2880.tif
# Saving tile to ./model/temp/tile_1536_2976.tif
# Saving tile to ./model/temp/tile_1536_3072.tif
# Saving tile to ./model/temp/tile_1536_3168.tif
# Saving tile to ./model/temp/tile_1536_3264.tif
# Saving tile to ./model/temp/tile_1536_3360.tif
# Saving tile to ./model/temp/tile_1632_0.tif
# Saving tile to ./model/temp/tile_1632_96.tif
# Saving tile to ./model/temp/tile_1632_192.tif
# Saving tile to ./model/temp/tile_1632_288.tif
# Saving tile to ./model/temp/tile_1632_384.tif
# Saving tile to ./model/temp/tile_1632_480.tif
# Saving tile to ./model/temp/tile_1632_576.tif
# Saving tile to ./model/temp/tile_1632_672.tif
# Saving tile to ./model/temp/tile_1632_768.tif
# Saving tile to ./model/temp/tile_1632_864.tif
# Saving tile to ./model/temp/tile_1632_960.tif
# Saving tile to ./model/temp/tile_1632_1056.tif
# Saving tile to ./model/temp/tile_1632_1152.tif
# Saving tile to ./model/temp/tile_1632_1248.tif
# Saving tile to ./model/temp/tile_1632_1344.tif
# Saving tile to ./model/temp/tile_1632_1440.tif
# Saving tile to ./model/temp/tile_1632_1536.tif
# Saving tile to ./model/temp/tile_1632_1632.tif
# Saving tile to ./model/temp/tile_1632_1728.tif
# Saving tile to ./model/temp/tile_1632_1824.tif
# Saving tile to ./model/temp/tile_1632_1920.tif
# Saving tile to ./model/temp/tile_1632_2016.tif
# Saving tile to ./model/temp/tile_1632_2112.tif
# Saving tile to ./model/temp/tile_1632_2208.tif
# Saving tile to ./model/temp/tile_1632_2304.tif
# Saving tile to ./model/temp/tile_1632_2400.tif
# Saving tile to ./model/temp/tile_1632_2496.tif
# Saving tile to ./model/temp/tile_1632_2592.tif
# Saving tile to ./model/temp/tile_1632_2688.tif
# Saving tile to ./model/temp/tile_1632_2784.tif
# Saving tile to ./model/temp/tile_1632_2880.tif
# Saving tile to ./model/temp/tile_1632_2976.tif
# Saving tile to ./model/temp/tile_1632_3072.tif
# Saving tile to ./model/temp/tile_1632_3168.tif
# Saving tile to ./model/temp/tile_1632_3264.tif
# Saving tile to ./model/temp/tile_1632_3360.tif
# Saving tile to ./model/temp/tile_1728_0.tif
# Saving tile to ./model/temp/tile_1728_96.tif
# Saving tile to ./model/temp/tile_1728_192.tif
# Saving tile to ./model/temp/tile_1728_288.tif
# Saving tile to ./model/temp/tile_1728_384.tif
# Saving tile to ./model/temp/tile_1728_480.tif
# Saving tile to ./model/temp/tile_1728_576.tif
# Saving tile to ./model/temp/tile_1728_672.tif
# Saving tile to ./model/temp/tile_1728_768.tif
# Saving tile to ./model/temp/tile_1728_864.tif
# Saving tile to ./model/temp/tile_1728_960.tif
# Saving tile to ./model/temp/tile_1728_1056.tif
# Saving tile to ./model/temp/tile_1728_1152.tif
# Saving tile to ./model/temp/tile_1728_1248.tif
# Saving tile to ./model/temp/tile_1728_1344.tif
# Saving tile to ./model/temp/tile_1728_1440.tif
# Saving tile to ./model/temp/tile_1728_1536.tif
# Saving tile to ./model/temp/tile_1728_1632.tif
# Saving tile to ./model/temp/tile_1728_1728.tif
# Saving tile to ./model/temp/tile_1728_1824.tif
# Saving tile to ./model/temp/tile_1728_1920.tif
# Saving tile to ./model/temp/tile_1728_2016.tif
# Saving tile to ./model/temp/tile_1728_2112.tif
# Saving tile to ./model/temp/tile_1728_2208.tif
# Saving tile to ./model/temp/tile_1728_2304.tif
# Saving tile to ./model/temp/tile_1728_2400.tif
# Saving tile to ./model/temp/tile_1728_2496.tif
# Saving tile to ./model/temp/tile_1728_2592.tif
# Saving tile to ./model/temp/tile_1728_2688.tif
# Saving tile to ./model/temp/tile_1728_2784.tif
# Saving tile to ./model/temp/tile_1728_2880.tif
# Saving tile to ./model/temp/tile_1728_2976.tif
# Saving tile to ./model/temp/tile_1728_3072.tif
# Saving tile to ./model/temp/tile_1728_3168.tif
# Saving tile to ./model/temp/tile_1728_3264.tif
# Saving tile to ./model/temp/tile_1728_3360.tif
# Saving tile to ./model/temp/tile_1824_0.tif
# Saving tile to ./model/temp/tile_1824_96.tif
# Saving tile to ./model/temp/tile_1824_192.tif
# Saving tile to ./model/temp/tile_1824_288.tif
# Saving tile to ./model/temp/tile_1824_384.tif
# Saving tile to ./model/temp/tile_1824_480.tif
# Saving tile to ./model/temp/tile_1824_576.tif
# Saving tile to ./model/temp/tile_1824_672.tif
# Saving tile to ./model/temp/tile_1824_768.tif
# Saving tile to ./model/temp/tile_1824_864.tif
# Saving tile to ./model/temp/tile_1824_960.tif
# Saving tile to ./model/temp/tile_1824_1056.tif
# Saving tile to ./model/temp/tile_1824_1152.tif
# Saving tile to ./model/temp/tile_1824_1248.tif
# Saving tile to ./model/temp/tile_1824_1344.tif
# Saving tile to ./model/temp/tile_1824_1440.tif
# Saving tile to ./model/temp/tile_1824_1536.tif
# Saving tile to ./model/temp/tile_1824_1632.tif
# Saving tile to ./model/temp/tile_1824_1728.tif
# Saving tile to ./model/temp/tile_1824_1824.tif
# Saving tile to ./model/temp/tile_1824_1920.tif
# Saving tile to ./model/temp/tile_1824_2016.tif
# Saving tile to ./model/temp/tile_1824_2112.tif
# Saving tile to ./model/temp/tile_1824_2208.tif
# Saving tile to ./model/temp/tile_1824_2304.tif
# Saving tile to ./model/temp/tile_1824_2400.tif
# Saving tile to ./model/temp/tile_1824_2496.tif
# Saving tile to ./model/temp/tile_1824_2592.tif
# Saving tile to ./model/temp/tile_1824_2688.tif
# Saving tile to ./model/temp/tile_1824_2784.tif
# Saving tile to ./model/temp/tile_1824_2880.tif
# Saving tile to ./model/temp/tile_1824_2976.tif
# Saving tile to ./model/temp/tile_1824_3072.tif
# Saving tile to ./model/temp/tile_1824_3168.tif
# Saving tile to ./model/temp/tile_1824_3264.tif
# Saving tile to ./model/temp/tile_1824_3360.tif
# Saving tile to ./model/temp/tile_1920_0.tif
# Saving tile to ./model/temp/tile_1920_96.tif
# Saving tile to ./model/temp/tile_1920_192.tif
# Saving tile to ./model/temp/tile_1920_288.tif
# Saving tile to ./model/temp/tile_1920_384.tif
# Saving tile to ./model/temp/tile_1920_480.tif
# Saving tile to ./model/temp/tile_1920_576.tif
# Saving tile to ./model/temp/tile_1920_672.tif
# Saving tile to ./model/temp/tile_1920_768.tif
# Saving tile to ./model/temp/tile_1920_864.tif
# Saving tile to ./model/temp/tile_1920_960.tif
# Saving tile to ./model/temp/tile_1920_1056.tif
# Saving tile to ./model/temp/tile_1920_1152.tif
# Saving tile to ./model/temp/tile_1920_1248.tif
# Saving tile to ./model/temp/tile_1920_1344.tif
# Saving tile to ./model/temp/tile_1920_1440.tif
# Saving tile to ./model/temp/tile_1920_1536.tif
# Saving tile to ./model/temp/tile_1920_1632.tif
# Saving tile to ./model/temp/tile_1920_1728.tif
# Saving tile to ./model/temp/tile_1920_1824.tif
# Saving tile to ./model/temp/tile_1920_1920.tif
# Saving tile to ./model/temp/tile_1920_2016.tif
# Saving tile to ./model/temp/tile_1920_2112.tif
# Saving tile to ./model/temp/tile_1920_2208.tif
# Saving tile to ./model/temp/tile_1920_2304.tif
# Saving tile to ./model/temp/tile_1920_2400.tif
# Saving tile to ./model/temp/tile_1920_2496.tif
# Saving tile to ./model/temp/tile_1920_2592.tif
# Saving tile to ./model/temp/tile_1920_2688.tif
# Saving tile to ./model/temp/tile_1920_2784.tif
# Saving tile to ./model/temp/tile_1920_2880.tif
# Saving tile to ./model/temp/tile_1920_2976.tif
# Saving tile to ./model/temp/tile_1920_3072.tif
# Saving tile to ./model/temp/tile_1920_3168.tif
# Saving tile to ./model/temp/tile_1920_3264.tif
# Saving tile to ./model/temp/tile_1920_3360.tif
# Saving tile to ./model/temp/tile_2016_0.tif
# Saving tile to ./model/temp/tile_2016_96.tif
# Saving tile to ./model/temp/tile_2016_192.tif
# Saving tile to ./model/temp/tile_2016_288.tif
# Saving tile to ./model/temp/tile_2016_384.tif
# Saving tile to ./model/temp/tile_2016_480.tif
# Saving tile to ./model/temp/tile_2016_576.tif
# Saving tile to ./model/temp/tile_2016_672.tif
# Saving tile to ./model/temp/tile_2016_768.tif
# Saving tile to ./model/temp/tile_2016_864.tif
# Saving tile to ./model/temp/tile_2016_960.tif
# Saving tile to ./model/temp/tile_2016_1056.tif
# Saving tile to ./model/temp/tile_2016_1152.tif
# Saving tile to ./model/temp/tile_2016_1248.tif
# Saving tile to ./model/temp/tile_2016_1344.tif
# Saving tile to ./model/temp/tile_2016_1440.tif
# Saving tile to ./model/temp/tile_2016_1536.tif
# Saving tile to ./model/temp/tile_2016_1632.tif
# Saving tile to ./model/temp/tile_2016_1728.tif
# Saving tile to ./model/temp/tile_2016_1824.tif
# Saving tile to ./model/temp/tile_2016_1920.tif
# Saving tile to ./model/temp/tile_2016_2016.tif
# Saving tile to ./model/temp/tile_2016_2112.tif
# Saving tile to ./model/temp/tile_2016_2208.tif
# Saving tile to ./model/temp/tile_2016_2304.tif
# Saving tile to ./model/temp/tile_2016_2400.tif
# Saving tile to ./model/temp/tile_2016_2496.tif
# Saving tile to ./model/temp/tile_2016_2592.tif
# Saving tile to ./model/temp/tile_2016_2688.tif
# Saving tile to ./model/temp/tile_2016_2784.tif
# Saving tile to ./model/temp/tile_2016_2880.tif
# Saving tile to ./model/temp/tile_2016_2976.tif
# Saving tile to ./model/temp/tile_2016_3072.tif
# Saving tile to ./model/temp/tile_2016_3168.tif
# Saving tile to ./model/temp/tile_2016_3264.tif
# Saving tile to ./model/temp/tile_2016_3360.tif
# Saving tile to ./model/temp/tile_2112_0.tif
# Saving tile to ./model/temp/tile_2112_96.tif
# Saving tile to ./model/temp/tile_2112_192.tif
# Saving tile to ./model/temp/tile_2112_288.tif
# Saving tile to ./model/temp/tile_2112_384.tif
# Saving tile to ./model/temp/tile_2112_480.tif
# Saving tile to ./model/temp/tile_2112_576.tif
# Saving tile to ./model/temp/tile_2112_672.tif
# Saving tile to ./model/temp/tile_2112_768.tif
# Saving tile to ./model/temp/tile_2112_864.tif
# Saving tile to ./model/temp/tile_2112_960.tif
# Saving tile to ./model/temp/tile_2112_1056.tif
# Saving tile to ./model/temp/tile_2112_1152.tif
# Saving tile to ./model/temp/tile_2112_1248.tif
# Saving tile to ./model/temp/tile_2112_1344.tif
# Saving tile to ./model/temp/tile_2112_1440.tif
# Saving tile to ./model/temp/tile_2112_1536.tif
# Saving tile to ./model/temp/tile_2112_1632.tif
# Saving tile to ./model/temp/tile_2112_1728.tif
# Saving tile to ./model/temp/tile_2112_1824.tif
# Saving tile to ./model/temp/tile_2112_1920.tif
# Saving tile to ./model/temp/tile_2112_2016.tif
# Saving tile to ./model/temp/tile_2112_2112.tif
# Saving tile to ./model/temp/tile_2112_2208.tif
# Saving tile to ./model/temp/tile_2112_2304.tif
# Saving tile to ./model/temp/tile_2112_2400.tif
# Saving tile to ./model/temp/tile_2112_2496.tif
# Saving tile to ./model/temp/tile_2112_2592.tif
# Saving tile to ./model/temp/tile_2112_2688.tif
# Saving tile to ./model/temp/tile_2112_2784.tif
# Saving tile to ./model/temp/tile_2112_2880.tif
# Saving tile to ./model/temp/tile_2112_2976.tif
# Saving tile to ./model/temp/tile_2112_3072.tif
# Saving tile to ./model/temp/tile_2112_3168.tif
# Saving tile to ./model/temp/tile_2112_3264.tif
# Saving tile to ./model/temp/tile_2112_3360.tif
# Saving tile to ./model/temp/tile_2208_0.tif
# Saving tile to ./model/temp/tile_2208_96.tif
# Saving tile to ./model/temp/tile_2208_192.tif
# Saving tile to ./model/temp/tile_2208_288.tif
# Saving tile to ./model/temp/tile_2208_384.tif
# Saving tile to ./model/temp/tile_2208_480.tif
# Saving tile to ./model/temp/tile_2208_576.tif
# Saving tile to ./model/temp/tile_2208_672.tif
# Saving tile to ./model/temp/tile_2208_768.tif
# Saving tile to ./model/temp/tile_2208_864.tif
# Saving tile to ./model/temp/tile_2208_960.tif
# Saving tile to ./model/temp/tile_2208_1056.tif
# Saving tile to ./model/temp/tile_2208_1152.tif
# Saving tile to ./model/temp/tile_2208_1248.tif
# Saving tile to ./model/temp/tile_2208_1344.tif
# Saving tile to ./model/temp/tile_2208_1440.tif
# Saving tile to ./model/temp/tile_2208_1536.tif
# Saving tile to ./model/temp/tile_2208_1632.tif
# Saving tile to ./model/temp/tile_2208_1728.tif
# Saving tile to ./model/temp/tile_2208_1824.tif
# Saving tile to ./model/temp/tile_2208_1920.tif
# Saving tile to ./model/temp/tile_2208_2016.tif
# Saving tile to ./model/temp/tile_2208_2112.tif
# Saving tile to ./model/temp/tile_2208_2208.tif
# Saving tile to ./model/temp/tile_2208_2304.tif
# Saving tile to ./model/temp/tile_2208_2400.tif
# Saving tile to ./model/temp/tile_2208_2496.tif
# Saving tile to ./model/temp/tile_2208_2592.tif
# Saving tile to ./model/temp/tile_2208_2688.tif
# Saving tile to ./model/temp/tile_2208_2784.tif
# Saving tile to ./model/temp/tile_2208_2880.tif
# Saving tile to ./model/temp/tile_2208_2976.tif
# Saving tile to ./model/temp/tile_2208_3072.tif
# Saving tile to ./model/temp/tile_2208_3168.tif
# Saving tile to ./model/temp/tile_2208_3264.tif
# Saving tile to ./model/temp/tile_2208_3360.tif
# Saving tile to ./model/temp/tile_2304_0.tif
# Saving tile to ./model/temp/tile_2304_96.tif
# Saving tile to ./model/temp/tile_2304_192.tif
# Saving tile to ./model/temp/tile_2304_288.tif
# Saving tile to ./model/temp/tile_2304_384.tif
# Saving tile to ./model/temp/tile_2304_480.tif
# Saving tile to ./model/temp/tile_2304_576.tif
# Saving tile to ./model/temp/tile_2304_672.tif
# Saving tile to ./model/temp/tile_2304_768.tif
# Saving tile to ./model/temp/tile_2304_864.tif
# Saving tile to ./model/temp/tile_2304_960.tif
# Saving tile to ./model/temp/tile_2304_1056.tif
# Saving tile to ./model/temp/tile_2304_1152.tif
# Saving tile to ./model/temp/tile_2304_1248.tif
# Saving tile to ./model/temp/tile_2304_1344.tif
# Saving tile to ./model/temp/tile_2304_1440.tif
# Saving tile to ./model/temp/tile_2304_1536.tif
# Saving tile to ./model/temp/tile_2304_1632.tif
# Saving tile to ./model/temp/tile_2304_1728.tif
# Saving tile to ./model/temp/tile_2304_1824.tif
# Saving tile to ./model/temp/tile_2304_1920.tif
# Saving tile to ./model/temp/tile_2304_2016.tif
# Saving tile to ./model/temp/tile_2304_2112.tif
# Saving tile to ./model/temp/tile_2304_2208.tif
# Saving tile to ./model/temp/tile_2304_2304.tif
# Saving tile to ./model/temp/tile_2304_2400.tif
# Saving tile to ./model/temp/tile_2304_2496.tif
# Saving tile to ./model/temp/tile_2304_2592.tif
# Saving tile to ./model/temp/tile_2304_2688.tif
# Saving tile to ./model/temp/tile_2304_2784.tif
# Saving tile to ./model/temp/tile_2304_2880.tif
# Saving tile to ./model/temp/tile_2304_2976.tif
# Saving tile to ./model/temp/tile_2304_3072.tif
# Saving tile to ./model/temp/tile_2304_3168.tif
# Saving tile to ./model/temp/tile_2304_3264.tif
# Saving tile to ./model/temp/tile_2304_3360.tif
# Saving tile to ./model/temp/tile_2400_0.tif
# Saving tile to ./model/temp/tile_2400_96.tif
# Saving tile to ./model/temp/tile_2400_192.tif
# Saving tile to ./model/temp/tile_2400_288.tif
# Saving tile to ./model/temp/tile_2400_384.tif
# Saving tile to ./model/temp/tile_2400_480.tif
# Saving tile to ./model/temp/tile_2400_576.tif
# Saving tile to ./model/temp/tile_2400_672.tif
# Saving tile to ./model/temp/tile_2400_768.tif
# Saving tile to ./model/temp/tile_2400_864.tif
# Saving tile to ./model/temp/tile_2400_960.tif
# Saving tile to ./model/temp/tile_2400_1056.tif
# Saving tile to ./model/temp/tile_2400_1152.tif
# Saving tile to ./model/temp/tile_2400_1248.tif
# Saving tile to ./model/temp/tile_2400_1344.tif
# Saving tile to ./model/temp/tile_2400_1440.tif
# Saving tile to ./model/temp/tile_2400_1536.tif
# Saving tile to ./model/temp/tile_2400_1632.tif
# Saving tile to ./model/temp/tile_2400_1728.tif
# Saving tile to ./model/temp/tile_2400_1824.tif
# Saving tile to ./model/temp/tile_2400_1920.tif
# Saving tile to ./model/temp/tile_2400_2016.tif
# Saving tile to ./model/temp/tile_2400_2112.tif
# Saving tile to ./model/temp/tile_2400_2208.tif
# Saving tile to ./model/temp/tile_2400_2304.tif
# Saving tile to ./model/temp/tile_2400_2400.tif
# Saving tile to ./model/temp/tile_2400_2496.tif
# Saving tile to ./model/temp/tile_2400_2592.tif
# Saving tile to ./model/temp/tile_2400_2688.tif
# Saving tile to ./model/temp/tile_2400_2784.tif
# Saving tile to ./model/temp/tile_2400_2880.tif
# Saving tile to ./model/temp/tile_2400_2976.tif
# Saving tile to ./model/temp/tile_2400_3072.tif
# Saving tile to ./model/temp/tile_2400_3168.tif
# Saving tile to ./model/temp/tile_2400_3264.tif
# Saving tile to ./model/temp/tile_2400_3360.tif
# Saving tile to ./model/temp/tile_2496_0.tif
# Saving tile to ./model/temp/tile_2496_96.tif
# Saving tile to ./model/temp/tile_2496_192.tif
# Saving tile to ./model/temp/tile_2496_288.tif
# Saving tile to ./model/temp/tile_2496_384.tif
# Saving tile to ./model/temp/tile_2496_480.tif
# Saving tile to ./model/temp/tile_2496_576.tif
# Saving tile to ./model/temp/tile_2496_672.tif
# Saving tile to ./model/temp/tile_2496_768.tif
# Saving tile to ./model/temp/tile_2496_864.tif
# Saving tile to ./model/temp/tile_2496_960.tif
# Saving tile to ./model/temp/tile_2496_1056.tif
# Saving tile to ./model/temp/tile_2496_1152.tif
# Saving tile to ./model/temp/tile_2496_1248.tif
# Saving tile to ./model/temp/tile_2496_1344.tif
# Saving tile to ./model/temp/tile_2496_1440.tif
# Saving tile to ./model/temp/tile_2496_1536.tif
# Saving tile to ./model/temp/tile_2496_1632.tif
# Saving tile to ./model/temp/tile_2496_1728.tif
# Saving tile to ./model/temp/tile_2496_1824.tif
# Saving tile to ./model/temp/tile_2496_1920.tif
# Saving tile to ./model/temp/tile_2496_2016.tif
# Saving tile to ./model/temp/tile_2496_2112.tif
# Saving tile to ./model/temp/tile_2496_2208.tif
# Saving tile to ./model/temp/tile_2496_2304.tif
# Saving tile to ./model/temp/tile_2496_2400.tif
# Saving tile to ./model/temp/tile_2496_2496.tif
# Saving tile to ./model/temp/tile_2496_2592.tif
# Saving tile to ./model/temp/tile_2496_2688.tif
# Saving tile to ./model/temp/tile_2496_2784.tif
# Saving tile to ./model/temp/tile_2496_2880.tif
# Saving tile to ./model/temp/tile_2496_2976.tif
# Saving tile to ./model/temp/tile_2496_3072.tif
# Saving tile to ./model/temp/tile_2496_3168.tif
# Saving tile to ./model/temp/tile_2496_3264.tif
# Saving tile to ./model/temp/tile_2496_3360.tif
# Saving tile to ./model/temp/tile_2592_0.tif
# Saving tile to ./model/temp/tile_2592_96.tif
# Saving tile to ./model/temp/tile_2592_192.tif
# Saving tile to ./model/temp/tile_2592_288.tif
# Saving tile to ./model/temp/tile_2592_384.tif
# Saving tile to ./model/temp/tile_2592_480.tif
# Saving tile to ./model/temp/tile_2592_576.tif
# Saving tile to ./model/temp/tile_2592_672.tif
# Saving tile to ./model/temp/tile_2592_768.tif
# Saving tile to ./model/temp/tile_2592_864.tif
# Saving tile to ./model/temp/tile_2592_960.tif
# Saving tile to ./model/temp/tile_2592_1056.tif
# Saving tile to ./model/temp/tile_2592_1152.tif
# Saving tile to ./model/temp/tile_2592_1248.tif
# Saving tile to ./model/temp/tile_2592_1344.tif
# Saving tile to ./model/temp/tile_2592_1440.tif
# Saving tile to ./model/temp/tile_2592_1536.tif
# Saving tile to ./model/temp/tile_2592_1632.tif
# Saving tile to ./model/temp/tile_2592_1728.tif
# Saving tile to ./model/temp/tile_2592_1824.tif
# Saving tile to ./model/temp/tile_2592_1920.tif
# Saving tile to ./model/temp/tile_2592_2016.tif
# Saving tile to ./model/temp/tile_2592_2112.tif
# Saving tile to ./model/temp/tile_2592_2208.tif
# Saving tile to ./model/temp/tile_2592_2304.tif
# Saving tile to ./model/temp/tile_2592_2400.tif
# Saving tile to ./model/temp/tile_2592_2496.tif
# Saving tile to ./model/temp/tile_2592_2592.tif
# Saving tile to ./model/temp/tile_2592_2688.tif
# Saving tile to ./model/temp/tile_2592_2784.tif
# Saving tile to ./model/temp/tile_2592_2880.tif
# Saving tile to ./model/temp/tile_2592_2976.tif
# Saving tile to ./model/temp/tile_2592_3072.tif
# Saving tile to ./model/temp/tile_2592_3168.tif
# Saving tile to ./model/temp/tile_2592_3264.tif
# Saving tile to ./model/temp/tile_2592_3360.tif
# Saving tile to ./model/temp/tile_2688_0.tif
# Saving tile to ./model/temp/tile_2688_96.tif
# Saving tile to ./model/temp/tile_2688_192.tif
# Saving tile to ./model/temp/tile_2688_288.tif
# Saving tile to ./model/temp/tile_2688_384.tif
# Saving tile to ./model/temp/tile_2688_480.tif
# Saving tile to ./model/temp/tile_2688_576.tif
# Saving tile to ./model/temp/tile_2688_672.tif
# Saving tile to ./model/temp/tile_2688_768.tif
# Saving tile to ./model/temp/tile_2688_864.tif
# Saving tile to ./model/temp/tile_2688_960.tif
# Saving tile to ./model/temp/tile_2688_1056.tif
# Saving tile to ./model/temp/tile_2688_1152.tif
# Saving tile to ./model/temp/tile_2688_1248.tif
# Saving tile to ./model/temp/tile_2688_1344.tif
# Saving tile to ./model/temp/tile_2688_1440.tif
# Saving tile to ./model/temp/tile_2688_1536.tif
# Saving tile to ./model/temp/tile_2688_1632.tif
# Saving tile to ./model/temp/tile_2688_1728.tif
# Saving tile to ./model/temp/tile_2688_1824.tif
# Saving tile to ./model/temp/tile_2688_1920.tif
# Saving tile to ./model/temp/tile_2688_2016.tif
# Saving tile to ./model/temp/tile_2688_2112.tif
# Saving tile to ./model/temp/tile_2688_2208.tif
# Saving tile to ./model/temp/tile_2688_2304.tif
# ...
# Saving prediction to ./model/temp_pred/tile_4128_1440.tif
# Saving prediction to ./model/temp_pred/tile_4128_1536.tif
# Saving prediction to ./model/temp_pred/tile_4128_1632.tif
# Saving prediction to ./model/temp_pred/tile_4128_1728.tif
# Saving prediction to ./model/temp_pred/tile_4128_1824.tif
# Saving prediction to ./model/temp_pred/tile_4128_1920.tif
# Saving prediction to ./model/temp_pred/tile_4128_2016.tif
# Saving prediction to ./model/temp_pred/tile_4128_2112.tif
# Saving prediction to ./model/temp_pred/tile_4128_2208.tif
# Predicting batch 132/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4128_2304.tif
# Saving prediction to ./model/temp_pred/tile_4128_2400.tif
# Saving prediction to ./model/temp_pred/tile_4128_2496.tif
# Saving prediction to ./model/temp_pred/tile_4128_2592.tif
# Saving prediction to ./model/temp_pred/tile_4128_2688.tif
# Saving prediction to ./model/temp_pred/tile_4128_2784.tif
# Saving prediction to ./model/temp_pred/tile_4128_2880.tif
# Saving prediction to ./model/temp_pred/tile_4128_2976.tif
# Saving prediction to ./model/temp_pred/tile_4128_3072.tif
# Saving prediction to ./model/temp_pred/tile_4128_3168.tif
# Saving prediction to ./model/temp_pred/tile_4128_3264.tif
# Saving prediction to ./model/temp_pred/tile_4128_3360.tif
# Predicting batch 133/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4224_0.tif
# Saving prediction to ./model/temp_pred/tile_4224_96.tif
# Saving prediction to ./model/temp_pred/tile_4224_192.tif
# Saving prediction to ./model/temp_pred/tile_4224_288.tif
# Saving prediction to ./model/temp_pred/tile_4224_384.tif
# Saving prediction to ./model/temp_pred/tile_4224_480.tif
# Saving prediction to ./model/temp_pred/tile_4224_576.tif
# Saving prediction to ./model/temp_pred/tile_4224_672.tif
# Saving prediction to ./model/temp_pred/tile_4224_768.tif
# Saving prediction to ./model/temp_pred/tile_4224_864.tif
# Saving prediction to ./model/temp_pred/tile_4224_960.tif
# Saving prediction to ./model/temp_pred/tile_4224_1056.tif
# Predicting batch 134/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4224_1152.tif
# Saving prediction to ./model/temp_pred/tile_4224_1248.tif
# Saving prediction to ./model/temp_pred/tile_4224_1344.tif
# Saving prediction to ./model/temp_pred/tile_4224_1440.tif
# Saving prediction to ./model/temp_pred/tile_4224_1536.tif
# Saving prediction to ./model/temp_pred/tile_4224_1632.tif
# Saving prediction to ./model/temp_pred/tile_4224_1728.tif
# Saving prediction to ./model/temp_pred/tile_4224_1824.tif
# Saving prediction to ./model/temp_pred/tile_4224_1920.tif
# Saving prediction to ./model/temp_pred/tile_4224_2016.tif
# Saving prediction to ./model/temp_pred/tile_4224_2112.tif
# Saving prediction to ./model/temp_pred/tile_4224_2208.tif
# Predicting batch 135/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4224_2304.tif
# Saving prediction to ./model/temp_pred/tile_4224_2400.tif
# Saving prediction to ./model/temp_pred/tile_4224_2496.tif
# Saving prediction to ./model/temp_pred/tile_4224_2592.tif
# Saving prediction to ./model/temp_pred/tile_4224_2688.tif
# Saving prediction to ./model/temp_pred/tile_4224_2784.tif
# Saving prediction to ./model/temp_pred/tile_4224_2880.tif
# Saving prediction to ./model/temp_pred/tile_4224_2976.tif
# Saving prediction to ./model/temp_pred/tile_4224_3072.tif
# Saving prediction to ./model/temp_pred/tile_4224_3168.tif
# Saving prediction to ./model/temp_pred/tile_4224_3264.tif
# Saving prediction to ./model/temp_pred/tile_4224_3360.tif
# Predicting batch 136/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4320_0.tif
# Saving prediction to ./model/temp_pred/tile_4320_96.tif
# Saving prediction to ./model/temp_pred/tile_4320_192.tif
# Saving prediction to ./model/temp_pred/tile_4320_288.tif
# Saving prediction to ./model/temp_pred/tile_4320_384.tif
# Saving prediction to ./model/temp_pred/tile_4320_480.tif
# Saving prediction to ./model/temp_pred/tile_4320_576.tif
# Saving prediction to ./model/temp_pred/tile_4320_672.tif
# Saving prediction to ./model/temp_pred/tile_4320_768.tif
# Saving prediction to ./model/temp_pred/tile_4320_864.tif
# Saving prediction to ./model/temp_pred/tile_4320_960.tif
# Saving prediction to ./model/temp_pred/tile_4320_1056.tif
# Predicting batch 137/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4320_1152.tif
# Saving prediction to ./model/temp_pred/tile_4320_1248.tif
# Saving prediction to ./model/temp_pred/tile_4320_1344.tif
# Saving prediction to ./model/temp_pred/tile_4320_1440.tif
# Saving prediction to ./model/temp_pred/tile_4320_1536.tif
# Saving prediction to ./model/temp_pred/tile_4320_1632.tif
# Saving prediction to ./model/temp_pred/tile_4320_1728.tif
# Saving prediction to ./model/temp_pred/tile_4320_1824.tif
# Saving prediction to ./model/temp_pred/tile_4320_1920.tif
# Saving prediction to ./model/temp_pred/tile_4320_2016.tif
# Saving prediction to ./model/temp_pred/tile_4320_2112.tif
# Saving prediction to ./model/temp_pred/tile_4320_2208.tif
# Predicting batch 138/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4320_2304.tif
# Saving prediction to ./model/temp_pred/tile_4320_2400.tif
# Saving prediction to ./model/temp_pred/tile_4320_2496.tif
# Saving prediction to ./model/temp_pred/tile_4320_2592.tif
# Saving prediction to ./model/temp_pred/tile_4320_2688.tif
# Saving prediction to ./model/temp_pred/tile_4320_2784.tif
# Saving prediction to ./model/temp_pred/tile_4320_2880.tif
# Saving prediction to ./model/temp_pred/tile_4320_2976.tif
# Saving prediction to ./model/temp_pred/tile_4320_3072.tif
# Saving prediction to ./model/temp_pred/tile_4320_3168.tif
# Saving prediction to ./model/temp_pred/tile_4320_3264.tif
# Saving prediction to ./model/temp_pred/tile_4320_3360.tif
# Predicting batch 139/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4416_0.tif
# Saving prediction to ./model/temp_pred/tile_4416_96.tif
# Saving prediction to ./model/temp_pred/tile_4416_192.tif
# Saving prediction to ./model/temp_pred/tile_4416_288.tif
# Saving prediction to ./model/temp_pred/tile_4416_384.tif
# Saving prediction to ./model/temp_pred/tile_4416_480.tif
# Saving prediction to ./model/temp_pred/tile_4416_576.tif
# Saving prediction to ./model/temp_pred/tile_4416_672.tif
# Saving prediction to ./model/temp_pred/tile_4416_768.tif
# Saving prediction to ./model/temp_pred/tile_4416_864.tif
# Saving prediction to ./model/temp_pred/tile_4416_960.tif
# Saving prediction to ./model/temp_pred/tile_4416_1056.tif
# Predicting batch 140/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4416_1152.tif
# Saving prediction to ./model/temp_pred/tile_4416_1248.tif
# Saving prediction to ./model/temp_pred/tile_4416_1344.tif
# Saving prediction to ./model/temp_pred/tile_4416_1440.tif
# Saving prediction to ./model/temp_pred/tile_4416_1536.tif
# Saving prediction to ./model/temp_pred/tile_4416_1632.tif
# Saving prediction to ./model/temp_pred/tile_4416_1728.tif
# Saving prediction to ./model/temp_pred/tile_4416_1824.tif
# Saving prediction to ./model/temp_pred/tile_4416_1920.tif
# Saving prediction to ./model/temp_pred/tile_4416_2016.tif
# Saving prediction to ./model/temp_pred/tile_4416_2112.tif
# Saving prediction to ./model/temp_pred/tile_4416_2208.tif
# Predicting batch 141/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4416_2304.tif
# Saving prediction to ./model/temp_pred/tile_4416_2400.tif
# Saving prediction to ./model/temp_pred/tile_4416_2496.tif
# Saving prediction to ./model/temp_pred/tile_4416_2592.tif
# Saving prediction to ./model/temp_pred/tile_4416_2688.tif
# Saving prediction to ./model/temp_pred/tile_4416_2784.tif
# Saving prediction to ./model/temp_pred/tile_4416_2880.tif
# Saving prediction to ./model/temp_pred/tile_4416_2976.tif
# Saving prediction to ./model/temp_pred/tile_4416_3072.tif
# Saving prediction to ./model/temp_pred/tile_4416_3168.tif
# Saving prediction to ./model/temp_pred/tile_4416_3264.tif
# Saving prediction to ./model/temp_pred/tile_4416_3360.tif
# Predicting batch 142/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4512_0.tif
# Saving prediction to ./model/temp_pred/tile_4512_96.tif
# Saving prediction to ./model/temp_pred/tile_4512_192.tif
# Saving prediction to ./model/temp_pred/tile_4512_288.tif
# Saving prediction to ./model/temp_pred/tile_4512_384.tif
# Saving prediction to ./model/temp_pred/tile_4512_480.tif
# Saving prediction to ./model/temp_pred/tile_4512_576.tif
# Saving prediction to ./model/temp_pred/tile_4512_672.tif
# Saving prediction to ./model/temp_pred/tile_4512_768.tif
# Saving prediction to ./model/temp_pred/tile_4512_864.tif
# Saving prediction to ./model/temp_pred/tile_4512_960.tif
# Saving prediction to ./model/temp_pred/tile_4512_1056.tif
# Predicting batch 143/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4512_1152.tif
# Saving prediction to ./model/temp_pred/tile_4512_1248.tif
# Saving prediction to ./model/temp_pred/tile_4512_1344.tif
# Saving prediction to ./model/temp_pred/tile_4512_1440.tif
# Saving prediction to ./model/temp_pred/tile_4512_1536.tif
# Saving prediction to ./model/temp_pred/tile_4512_1632.tif
# Saving prediction to ./model/temp_pred/tile_4512_1728.tif
# Saving prediction to ./model/temp_pred/tile_4512_1824.tif
# Saving prediction to ./model/temp_pred/tile_4512_1920.tif
# Saving prediction to ./model/temp_pred/tile_4512_2016.tif
# Saving prediction to ./model/temp_pred/tile_4512_2112.tif
# Saving prediction to ./model/temp_pred/tile_4512_2208.tif
# Predicting batch 144/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4512_2304.tif
# Saving prediction to ./model/temp_pred/tile_4512_2400.tif
# Saving prediction to ./model/temp_pred/tile_4512_2496.tif
# Saving prediction to ./model/temp_pred/tile_4512_2592.tif
# Saving prediction to ./model/temp_pred/tile_4512_2688.tif
# Saving prediction to ./model/temp_pred/tile_4512_2784.tif
# Saving prediction to ./model/temp_pred/tile_4512_2880.tif
# Saving prediction to ./model/temp_pred/tile_4512_2976.tif
# Saving prediction to ./model/temp_pred/tile_4512_3072.tif
# Saving prediction to ./model/temp_pred/tile_4512_3168.tif
# Saving prediction to ./model/temp_pred/tile_4512_3264.tif
# Saving prediction to ./model/temp_pred/tile_4512_3360.tif
# Predicting batch 145/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4608_0.tif
# Saving prediction to ./model/temp_pred/tile_4608_96.tif
# Saving prediction to ./model/temp_pred/tile_4608_192.tif
# Saving prediction to ./model/temp_pred/tile_4608_288.tif
# Saving prediction to ./model/temp_pred/tile_4608_384.tif
# Saving prediction to ./model/temp_pred/tile_4608_480.tif
# Saving prediction to ./model/temp_pred/tile_4608_576.tif
# Saving prediction to ./model/temp_pred/tile_4608_672.tif
# Saving prediction to ./model/temp_pred/tile_4608_768.tif
# Saving prediction to ./model/temp_pred/tile_4608_864.tif
# Saving prediction to ./model/temp_pred/tile_4608_960.tif
# Saving prediction to ./model/temp_pred/tile_4608_1056.tif
# Predicting batch 146/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4608_1152.tif
# Saving prediction to ./model/temp_pred/tile_4608_1248.tif
# Saving prediction to ./model/temp_pred/tile_4608_1344.tif
# Saving prediction to ./model/temp_pred/tile_4608_1440.tif
# Saving prediction to ./model/temp_pred/tile_4608_1536.tif
# Saving prediction to ./model/temp_pred/tile_4608_1632.tif
# Saving prediction to ./model/temp_pred/tile_4608_1728.tif
# Saving prediction to ./model/temp_pred/tile_4608_1824.tif
# Saving prediction to ./model/temp_pred/tile_4608_1920.tif
# Saving prediction to ./model/temp_pred/tile_4608_2016.tif
# Saving prediction to ./model/temp_pred/tile_4608_2112.tif
# Saving prediction to ./model/temp_pred/tile_4608_2208.tif
# Predicting batch 147/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4608_2304.tif
# Saving prediction to ./model/temp_pred/tile_4608_2400.tif
# Saving prediction to ./model/temp_pred/tile_4608_2496.tif
# Saving prediction to ./model/temp_pred/tile_4608_2592.tif
# Saving prediction to ./model/temp_pred/tile_4608_2688.tif
# Saving prediction to ./model/temp_pred/tile_4608_2784.tif
# Saving prediction to ./model/temp_pred/tile_4608_2880.tif
# Saving prediction to ./model/temp_pred/tile_4608_2976.tif
# Saving prediction to ./model/temp_pred/tile_4608_3072.tif
# Saving prediction to ./model/temp_pred/tile_4608_3168.tif
# Saving prediction to ./model/temp_pred/tile_4608_3264.tif
# Saving prediction to ./model/temp_pred/tile_4608_3360.tif
# Predicting batch 148/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4704_0.tif
# Saving prediction to ./model/temp_pred/tile_4704_96.tif
# Saving prediction to ./model/temp_pred/tile_4704_192.tif
# Saving prediction to ./model/temp_pred/tile_4704_288.tif
# Saving prediction to ./model/temp_pred/tile_4704_384.tif
# Saving prediction to ./model/temp_pred/tile_4704_480.tif
# Saving prediction to ./model/temp_pred/tile_4704_576.tif
# Saving prediction to ./model/temp_pred/tile_4704_672.tif
# Saving prediction to ./model/temp_pred/tile_4704_768.tif
# Saving prediction to ./model/temp_pred/tile_4704_864.tif
# Saving prediction to ./model/temp_pred/tile_4704_960.tif
# Saving prediction to ./model/temp_pred/tile_4704_1056.tif
# Predicting batch 149/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4704_1152.tif
# Saving prediction to ./model/temp_pred/tile_4704_1248.tif
# Saving prediction to ./model/temp_pred/tile_4704_1344.tif
# Saving prediction to ./model/temp_pred/tile_4704_1440.tif
# Saving prediction to ./model/temp_pred/tile_4704_1536.tif
# Saving prediction to ./model/temp_pred/tile_4704_1632.tif
# Saving prediction to ./model/temp_pred/tile_4704_1728.tif
# Saving prediction to ./model/temp_pred/tile_4704_1824.tif
# Saving prediction to ./model/temp_pred/tile_4704_1920.tif
# Saving prediction to ./model/temp_pred/tile_4704_2016.tif
# Saving prediction to ./model/temp_pred/tile_4704_2112.tif
# Saving prediction to ./model/temp_pred/tile_4704_2208.tif
# Predicting batch 150/150
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to ./model/temp_pred/tile_4704_2304.tif
# Saving prediction to ./model/temp_pred/tile_4704_2400.tif
# Saving prediction to ./model/temp_pred/tile_4704_2496.tif
# Saving prediction to ./model/temp_pred/tile_4704_2592.tif
# Saving prediction to ./model/temp_pred/tile_4704_2688.tif
# Saving prediction to ./model/temp_pred/tile_4704_2784.tif
# Saving prediction to ./model/temp_pred/tile_4704_2880.tif
# Saving prediction to ./model/temp_pred/tile_4704_2976.tif
# Saving prediction to ./model/temp_pred/tile_4704_3072.tif
# Saving prediction to ./model/temp_pred/tile_4704_3168.tif
# Saving prediction to ./model/temp_pred/tile_4704_3264.tif
# Saving prediction to ./model/temp_pred/tile_4704_3360.tif
# Saving full raster to ./model/Swin_UNETR/Aug/M1_selected_L5_S2_S1_MSRM_PCA_N48-0000000000-0000000000_swinunetr.tif
# Merging tiles back into full image of shape (1, 4864, 3456)
# Creating .tfw file at ./model/Swin_UNETR/Aug/M1_selected_L5_S2_S1_MSRM_PCA_N48-0000000000-0000000000_swinunetr.tfw
# Prediction, saving, and .tfw file creation complete
