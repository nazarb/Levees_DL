# %% [markdown]
# <a href="https://colab.research.google.com/github/nazarb/2025_levees_DL/blob/main/swin_unetr_demo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Levee detection demo
#
# The file contains the demonstation of the Swin UNETR model for detection of the levees. The original model is run in the Docker enviroment, which published in the Git repository
#
# This versin of the model can predict the levees, run post-processing and save the results

# %%
# !git clone https://github.com/nazarb/2025_levees_DL.git
# Out:
# Cloning into '2025_levees_DL'...
# remote: Enumerating objects: 626, done.
# remote: Counting objects: 100% (292/292), done.
# remote: Compressing objects: 100% (230/230), done.
# remote: Total 626 (delta 154), reused 15 (delta 15), pack-reused 334 (from 2)
# Receiving objects: 100% (626/626), 1.42 MiB | 5.80 MiB/s, done.
# Resolving deltas: 100% (279/279), done.

# %% [markdown]
# \## Set up path for further processing

# %%
import os
basepath = os.getcwd()
print(basepath)
# set other paths for quick navigation
git_path = os.path.join(basepath, "2025_levees_DL")
print(git_path)
Swin_UNETR_path = os.path.join(git_path, "Swin_UNETR")
print(Swin_UNETR_path)
results_path = os.path.join(Swin_UNETR_path, "results/Swin_UNETR/Aug")
os.makedirs(results_path, exist_ok=True)
print(results_path)
# Out:
# /content
# /content/2025_levees_DL
# /content/2025_levees_DL/Swin_UNETR
# /content/2025_levees_DL/Swin_UNETR/results/Swin_UNETR/Aug

# %%
# !pip install --no-cache-dir monai==1.3.2
# Out:
# Collecting monai==1.3.2
#   Downloading monai-1.3.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.12/dist-packages (from monai==1.3.2) (2.8.0+cu126)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.12/dist-packages (from monai==1.3.2) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (3.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.2) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.9->monai==1.3.2) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.9->monai==1.3.2) (3.0.3)
# Downloading monai-1.3.2-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 56.3 MB/s eta 0:00:00
# Installing collected packages: monai
# Successfully installed monai-1.3.2

# %%
# !sudo apt install megatools
# !pip install rasterio
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   megatools
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 207 kB of archives.
# After this operation, 898 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 megatools amd64 1.10.3-1build1 [207 kB]
# Fetched 207 kB in 0s (1,668 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package megatools.
# (Reading database ... 126675 files and directories currently installed.)
# Preparing to unpack .../megatools_1.10.3-1build1_amd64.deb ...
# Unpacking megatools (1.10.3-1build1) ...
# Setting up megatools (1.10.3-1build1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting rasterio
#   Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.1 kB)
# Collecting affine (from rasterio)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2025.10.5)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.0)
# Collecting cligj>=0.5 (from rasterio)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Collecting click-plugins (from rasterio)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.5)
# Downloading rasterio-1.4.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (22.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 62.8 MB/s eta 0:00:00
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Installing collected packages: cligj, click-plugins, affine, rasterio
# Successfully installed affine-2.4.0 click-plugins-1.1.1.2 cligj-0.7.2 rasterio-1.4.3

# %%
import warnings
warnings.filterwarnings("ignore")
import torch
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
torch.cuda.is_available()
torch.cuda.device_count()
torch.cuda.current_device()
torch.cuda.get_device_name(0)
# Out:
# 'Tesla T4'

# %% [markdown]
# ## Download the data and the model
#
# The raster data used in this study is calculated with the provided Google Earth Engine code. The model is published in the Dane Badawcze UW repository (Published version: 2025-09-24):
#
# ```
# Buławka, Nazarij; Orengo, Hector A.; Lumbreras Ruiz, Felipe; Berganzo-Besga, Iban; Gupta, Ekta, 2025, "Traces of ancient irrigation in central Iraq detected using deep learning model", https://doi.org/10.58132/MY8CCL, Dane Badawcze UW, V1
# ```

# %%
import os
import shutil
import requests
import os
import shutil

# Download data the raster calculated with provided Google Earth Engine code


# MEGA file URL
mega_url = "https://mega.nz/file/E9gBCCjR#UCDklOgOVOwQ0hRAIy5pvAdX9Y-VLBQktDlsrj4R1Ms"

# Temporary download path (megadl saves the file with original name by default)
download_dir = "/content"
downloaded_file = os.path.join(download_dir, "CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48.tif")

# Target directory
target_dir1 = f'{Swin_UNETR_path}/data'
os.makedirs(target_dir1, exist_ok=True)

# Download file using megadl
# !megadl "{mega_url}" --path "{download_dir}"

# Move the file to target directory (if needed rename)
shutil.move(downloaded_file, os.path.join(target_dir1, "CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48.tif"))
print(f"File moved to: {target_dir1}")

image_path = os.path.join(target_dir1, "CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48.tif")
# Out:
# Downloaded CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48.tif
# File moved to: /content/2025_levees_DL/Swin_UNETR/data

# %%
# Download the model from the Dane Badawcze UW repository (Published version: 2025-09-24):
## Buławka, Nazarij; Orengo, Hector A.; Lumbreras Ruiz, Felipe; Berganzo-Besga, Iban; Gupta, Ekta, 2025, "Traces of ancient irrigation in central Iraq detected using deep learning model", https://doi.org/10.58132/MY8CCL, Dane Badawcze UW, V1

## URL of the file
url = "https://danebadawcze.uw.edu.pl/api/access/datafile/17759"

## Download location
download_path = "/content/Levees_SWINUNETR_48_best.pth"

## Target directory
target_dir2 = f'{Swin_UNETR_path}/model/Swin_UNETR/Aug'
os.makedirs(target_dir2, exist_ok=True)  # create dir if it doesn't exist

## Download the file
print("Downloading...")
response = requests.get(url, stream=True)
with open(download_path, "wb") as f:
    shutil.copyfileobj(response.raw, f)
print("Download complete.")

3# Move to target directory
final_path = os.path.join(target_dir2, "Levees_SWINUNETR_48_best.pth")
shutil.move(download_path, final_path)
print(f"File moved to: {final_path}")
# Out:
# Downloading...
# Download complete.
# File moved to: /content/2025_levees_DL/Swin_UNETR/model/Swin_UNETR/Aug/Levees_SWINUNETR_48_best.pth

# %%
## Predict

Swin_UNETR_pth = os.path.join(target_dir2, "Levees_SWINUNETR_48_best.pth")
print({Swin_UNETR_pth})
data_path =  os.path.join(target_dir1, "CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48.tif")
print(data_path)
# Out:
# {'/content/2025_levees_DL/Swin_UNETR/model/Swin_UNETR/Aug/Levees_SWINUNETR_48_best.pth'}
# /content/2025_levees_DL/Swin_UNETR/data/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48.tif

# %%
import monai
from monai.inferers import sliding_window_inference
from monai.networks.nets import SwinUNETR
import einops
import warnings
import json
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import os
import rasterio
from rasterio.windows import Window
import tifffile as tiff


def get_filename_without_extension():
    data_to_detect = image_path
    filename_to_detect = os.path.splitext(os.path.basename(data_to_detect))[0]
    return filename_to_detect
filename_to_detect = get_filename_without_extension()

class NumpyDataset(Dataset):
    def __init__(self, image_paths, label_data):
        self.image_paths = image_paths
        self.label_data = label_data  # Accept either paths or preloaded arrays

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        image = np.load(self.image_paths[idx])

        # Check if label_data contains paths or arrays
        if isinstance(self.label_data[idx], str):
            label = np.load(self.label_data[idx])
        else:
            label = self.label_data[idx]

        image = self.replace_nans_in_array(image)
        label = self.replace_nans_in_array(label)

        image = torch.tensor(image, dtype=torch.float32)
        label = torch.tensor(label, dtype=torch.float32)

        return image, label, self.image_paths[idx]

    @staticmethod
    def replace_nans_in_array(arr):
        arr[np.isnan(arr)] = 0
        arr[np.isinf(arr)] = 0
        return arr


def load_dataset_json(json_path):
    with open(json_path, 'r') as file:
        dataset_json = json.load(file)
    return dataset_json

def prepare_test_loader(test_image_paths, batch_size):
    dummy_label_dir = "./model/temp_labels/"
    if not os.path.exists(dummy_label_dir):
        os.makedirs(dummy_label_dir)

    test_labels = []
    for image_path in test_image_paths:
        dummy_label_path = os.path.join(dummy_label_dir, os.path.basename(image_path).replace('.npy', '_label.npy'))
        np.save(dummy_label_path, np.zeros_like(np.load(image_path)))
        test_labels.append(dummy_label_path)

    test_dataset = NumpyDataset(test_image_paths, test_labels)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=4)

    return test_loader

def initialize_model():
    """Initialize the SwinUNETR model."""
    model = SwinUNETR(
        img_size=(96, 96),
        in_channels=48,
        out_channels=1,  # Use the passed `num_classes`
        use_checkpoint=True,
        feature_size=48,
        depths=(3, 9, 18, 3),
        num_heads=(4, 8, 16, 32),
        drop_rate=0.1,  # Added dropout
        attn_drop_rate=0.1,
        dropout_path_rate=0.2,
        spatial_dims=2
    )
    return model


def load_adapted_model(model, checkpoint_path):
    checkpoint = torch.load(checkpoint_path, map_location='cpu')
    model.load_state_dict(checkpoint, strict=False)
    return model

### Load model

def load_large_image(image_path):
    print(f"Loading large image from {image_path}")
    with rasterio.open(image_path) as src:
        image = src.read()
        transform = src.transform  # Capture the affine transformation matrix
    return image, transform

def split_to_tiles(image, tile_size, save_dir):
    print(f"Splitting image into tiles of size {tile_size}x{tile_size}")
    tiles = []
    num_channels, height, width = image.shape
    for i in range(0, height, tile_size):
        for j in range(0, width, tile_size):
            window = Window(j, i, tile_size, tile_size)
            tile = image[:, i:i+tile_size, j:j+tile_size]
            if tile.shape[1] == tile_size and tile.shape[2] == tile_size:
                tile_path = os.path.join(save_dir, f'tile_{i}_{j}.tif')
                print(f"Saving tile to {tile_path}")
                tiff.imwrite(tile_path, tile)
                tiles.append(tile_path)
    print(f"Total number of tiles: {len(tiles)}")
    return tiles

def convert_tiles_to_npy(tile_paths, npy_dir):
    if not os.path.exists(npy_dir):
        os.makedirs(npy_dir)
    npy_paths = []
    for tile_path in tile_paths:
        image = tiff.imread(tile_path)
        npy_path = os.path.join(npy_dir, os.path.basename(tile_path).replace('.tif', '.npy'))
        print(f"Converting {tile_path} to {npy_path}")
        np.save(npy_path, image)
        npy_paths.append(npy_path)
    return npy_paths

def merge_tiles(tiles, image_shape, tile_size):
    print(f"Merging tiles back into full image of shape {image_shape}")
    _, height, width = image_shape  # Assume image_shape is in the format (num_channels, height, width)
    full_image = np.zeros((height, width), dtype=np.uint8)  # Only one channel for the full image

    for tile_path in tiles:
        tile = tiff.imread(tile_path)
        # Adjust the parsing to match the filename pattern used in split_to_tiles
        filename = os.path.basename(tile_path)
        parts = filename.replace('tile_', '').replace('.tif', '').split('_')
        if len(parts) == 2:  # Ensure the filename format is correct
            i, j = map(int, parts)
            full_image[i:i+tile_size, j:j+tile_size] = tile  # Single channel tile assignment
        else:
            print(f"Unexpected filename format: {filename}")

    return full_image
###

def predict_and_save(model, test_loader, device, tile_paths, save_dir='model/temp_pred'):
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    print(f"Starting prediction on device: {device}")
    model.eval()
    model.to(device)
    predictions = []

    with torch.no_grad():
        for batch_idx, batch in enumerate(test_loader):
            images, _, _ = batch  # Unpack the batch; labels and paths are not needed for predictions
            print(f"Predicting batch {batch_idx + 1}/{len(test_loader)}")
            print(f"Images type: {type(images)}, Images shape: {images.shape if isinstance(images, torch.Tensor) else 'unknown'}")

            images = images.to(device)  # Move images to the correct device
            outputs = model(images)
            outputs = torch.sigmoid(outputs)
            outputs = outputs.cpu().numpy()

            # Save the predictions for each image in the batch
            for i in range(images.shape[0]):
                output_image = outputs[i]
                binary_output = (output_image > 0.5).astype(np.uint8)  # Apply threshold to create binary output
                original_tile_name = os.path.basename(tile_paths[batch_idx * test_loader.batch_size + i]).replace('.npy', '.tif')
                save_path = os.path.join(save_dir, original_tile_name)
                print(f"Saving prediction to {save_path}")
                tiff.imwrite(save_path, binary_output)
                predictions.append(save_path)

    return predictions



def save_full_raster(predictions, image_shape, tile_size, save_path):
    print(f"Saving full raster to {save_path}")
    full_raster = merge_tiles(predictions, image_shape, tile_size)
    with rasterio.open(save_path, 'w', driver='GTiff', height=full_raster.shape[0],
                       width=full_raster.shape[1], count=1, dtype=full_raster.dtype) as dst:
        dst.write(full_raster, 1)

def create_tfw_file(transform, tfw_path):
    print(f"Creating .tfw file at {tfw_path}")
    with open(tfw_path, 'w') as f:
        f.write(f"{transform.a}\n")  # pixel size in the x-direction
        f.write(f"{transform.b}\n")  # rotation term (always 0 for north-up images)
        f.write(f"{transform.d}\n")  # rotation term (always 0 for north-up images)
        f.write(f"{transform.e}\n")  # pixel size in the y-direction (usually negative)
        f.write(f"{transform.c}\n")  # x-coordinate of the upper-left corner of the upper-left pixel
        f.write(f"{transform.f}\n")  # y-coordinate of the upper-left corner of the upper-left pixel

if __name__ == "__main__":
    image_path = data_path

    tile_size = 96
    batch_size = 12
    model = initialize_model()

    print("Loading and preprocessing the large image")
    large_image, transform = load_large_image(image_path)
    large_image = NumpyDataset.replace_nans_in_array(large_image)
    image_shape = large_image.shape
    print(f"Large image shape: {image_shape}")

    temp_dir = f'{Swin_UNETR_path}/results/temp/'
    npy_dir = f'{Swin_UNETR_path}/results/temp_npy/'
    pred_dir = f'{Swin_UNETR_path}/results/temp_pred/'
    result_path = f'{Swin_UNETR_path}/results/Swin_UNETR/Aug/{filename_to_detect}_swinunetr.tif'
    tfw_path = f'{Swin_UNETR_path}/results/Swin_UNETR/Aug/{filename_to_detect}_swinunetr.tfw'

    if not os.path.exists(temp_dir):
        os.makedirs(temp_dir)

    tile_paths = split_to_tiles(large_image, tile_size, temp_dir)
    npy_paths = convert_tiles_to_npy(tile_paths, npy_dir)
    test_loader = prepare_test_loader(npy_paths, batch_size)

    adapted_model_path = Swin_UNETR_pth
    model = load_adapted_model(model, adapted_model_path)

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

    predictions = predict_and_save(model, test_loader, device, tile_paths, save_dir=pred_dir)

    # Adjust the image_shape to reflect the single-channel output
    single_channel_image_shape = (1, image_shape[1], image_shape[2])
    save_full_raster(predictions, single_channel_image_shape, tile_size, result_path)

    # Create the .tfw file using the transform from the original large image
    create_tfw_file(transform, tfw_path)

    print("Prediction, saving, and .tfw file creation complete")
# Out:
# Loading and preprocessing the large image
# Loading large image from /content/2025_levees_DL/Swin_UNETR/data/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48.tif
# Large image shape: (48, 2994, 1746)
# Splitting image into tiles of size 96x96
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_96_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_192_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_288_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_384_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_480_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_576_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_672_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_768_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_864_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_960_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1056_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1152_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1248_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1344_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1440_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1536_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1632_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1728_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1824_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_1920_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2016_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2112_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2208_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2304_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2400_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2496_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2592_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2688_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2784_1632.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_0.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_96.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_192.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_288.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_384.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_480.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_576.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_672.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_768.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_864.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_960.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_1056.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_1152.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_1248.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_1344.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_1440.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_1536.tif
# Saving tile to /content/2025_levees_DL/Swin_UNETR/results/temp/tile_2880_1632.tif
# Total number of tiles: 558
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_0.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_0.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_96.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_96.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_192.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_192.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_288.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_288.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_384.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_384.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_480.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_480.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_576.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_576.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_672.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_672.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_768.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_768.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_864.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_864.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_960.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_960.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1056.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_1056.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1152.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_1152.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1248.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_1248.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1344.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_1344.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1440.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_1440.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1536.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_1536.npy
# Converting /content/2025_levees_DL/Swin_UNETR/results/temp/tile_0_1632.tif to /content/2025_levees_DL/Swin_UNETR/results/temp_npy/tile_0_1632.npy
# ...
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2112_768.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2112_864.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2112_960.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2112_1056.tif
# Predicting batch 35/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2112_1152.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2112_1248.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2112_1344.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2112_1440.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2112_1536.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2112_1632.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_0.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_96.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_192.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_288.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_384.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_480.tif
# Predicting batch 36/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_576.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_672.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_768.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_864.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_960.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_1056.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_1152.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_1248.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_1344.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_1440.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_1536.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2208_1632.tif
# Predicting batch 37/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_0.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_96.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_192.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_288.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_384.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_480.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_576.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_672.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_768.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_864.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_960.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_1056.tif
# Predicting batch 38/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_1152.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_1248.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_1344.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_1440.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_1536.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2304_1632.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_0.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_96.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_192.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_288.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_384.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_480.tif
# Predicting batch 39/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_576.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_672.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_768.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_864.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_960.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_1056.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_1152.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_1248.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_1344.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_1440.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_1536.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2400_1632.tif
# Predicting batch 40/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_0.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_96.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_192.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_288.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_384.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_480.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_576.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_672.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_768.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_864.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_960.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_1056.tif
# Predicting batch 41/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_1152.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_1248.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_1344.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_1440.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_1536.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2496_1632.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_0.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_96.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_192.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_288.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_384.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_480.tif
# Predicting batch 42/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_576.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_672.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_768.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_864.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_960.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_1056.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_1152.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_1248.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_1344.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_1440.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_1536.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2592_1632.tif
# Predicting batch 43/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_0.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_96.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_192.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_288.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_384.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_480.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_576.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_672.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_768.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_864.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_960.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_1056.tif
# Predicting batch 44/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_1152.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_1248.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_1344.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_1440.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_1536.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2688_1632.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_0.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_96.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_192.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_288.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_384.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_480.tif
# Predicting batch 45/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_576.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_672.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_768.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_864.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_960.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_1056.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_1152.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_1248.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_1344.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_1440.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_1536.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2784_1632.tif
# Predicting batch 46/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([12, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_0.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_96.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_192.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_288.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_384.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_480.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_576.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_672.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_768.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_864.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_960.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_1056.tif
# Predicting batch 47/47
# Images type: <class 'torch.Tensor'>, Images shape: torch.Size([6, 48, 96, 96])
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_1152.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_1248.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_1344.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_1440.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_1536.tif
# Saving prediction to /content/2025_levees_DL/Swin_UNETR/results/temp_pred/tile_2880_1632.tif
# Saving full raster to /content/2025_levees_DL/Swin_UNETR/results/Swin_UNETR/Aug/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48_swinunetr.tif
# Merging tiles back into full image of shape (1, 2994, 1746)
# Creating .tfw file at /content/2025_levees_DL/Swin_UNETR/results/Swin_UNETR/Aug/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48_swinunetr.tfw
# Prediction, saving, and .tfw file creation complete

# %%
import numpy as np
import cv2
import os
import rasterio
from skimage import io
from skimage.morphology import thin
from scipy.ndimage import distance_transform_edt
from skimage.morphology import skeletonize

# ====== INPUT data ======
# raster_r = input("Enter path to raster data: ").strip('"') # change to process other files
raster_r = result_path
def get_filename_without_extension():
    return os.path.splitext(os.path.basename(raster_r))[0]
filename_to_detect = get_filename_without_extension()
def load_large_image(image_path):
    print(f"Loading large image from {image_path}")
    with rasterio.open(image_path) as src:
        image = src.read(1)  # Read first band
        transform = src.transform
    return image, transform

binary_raster, transform = load_large_image(raster_r)
binary_raster = (binary_raster > 0).astype(np.uint8)  # Ensure binary

# REMOVE SMALL OBJECTS
min_area = 350
num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(binary_raster, connectivity=8)

# Keep only features above the selected min_area parameter
filtered_raster = np.zeros_like(binary_raster, dtype=np.uint8)
for i in range(1, num_labels):  # skip background
    if stats[i, cv2.CC_STAT_AREA] >= min_area:
        filtered_raster[labels == i] = 1

# Save TFW file to preserve geographic location
def create_tfw_file(transform, tfw_path):
    print(f"Creating .tfw file at {tfw_path}")
    with open(tfw_path, 'w') as f:
        f.write(f"{transform.a}\n")
        f.write(f"{transform.b}\n")
        f.write(f"{transform.d}\n")
        f.write(f"{transform.e}\n")
        f.write(f"{transform.c}\n")
        f.write(f"{transform.f}\n")

# Output
output_dir = results_path
os.makedirs(output_dir, exist_ok=True)
filtered_dir = os.path.join(output_dir, "Filtered")
os.makedirs(filtered_dir, exist_ok=True)

# Save
filtered_tif_path = os.path.join(filtered_dir, f'{filename_to_detect}_filtered.tif')
io.imsave(filtered_tif_path, (filtered_raster * 1).astype(np.uint8))
create_tfw_file(transform, os.path.splitext(filtered_tif_path)[0] + '.tfw')

print("Filtering complete. Small features removed and .tfw file saved.")

# CLOSING
kernel = np.ones((7,7),np.uint8)
closing_raster = cv2.morphologyEx(filtered_raster, cv2.MORPH_CLOSE, kernel)

# SAVE CLOSING results
closing_tif_path = os.path.join(filtered_dir, f'{filename_to_detect}_closing.tif')
cv2.imwrite(closing_tif_path, (closing_raster * 1).astype(np.uint8))
create_tfw_file(transform, os.path.splitext(closing_tif_path)[0] + '.tfw')


# Skeletonize
skeletonize_raster = skeletonize(closing_raster > 0, method='lee')
skeletonize_raster = (skeletonize_raster * 1).astype(np.uint8)

# Save the final results
skeletonize_raster_tif_path = os.path.join(output_dir, f'{filename_to_detect}_skeletonize.tif')
cv2.imwrite(skeletonize_raster_tif_path, skeletonize_raster)
create_tfw_file(transform, os.path.splitext(skeletonize_raster_tif_path)[0] + '.tfw')
# Out:
# Loading large image from /content/2025_levees_DL/Swin_UNETR/results/Swin_UNETR/Aug/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48_swinunetr.tif
# Creating .tfw file at /content/2025_levees_DL/Swin_UNETR/results/Swin_UNETR/Aug/Filtered/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48_swinunetr_filtered.tfw
# Filtering complete. Small features removed and .tfw file saved.
# Creating .tfw file at /content/2025_levees_DL/Swin_UNETR/results/Swin_UNETR/Aug/Filtered/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48_swinunetr_closing.tfw
# Creating .tfw file at /content/2025_levees_DL/Swin_UNETR/results/Swin_UNETR/Aug/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48_swinunetr_skeletonize.tfw

# %%
# MEGA file URL
mega_url2 = "https://mega.nz/file/5txRRQiZ#dDRqdI4F695r7yG465W5KIISVdQ1Iw2O8EWK2BIdoFs"

# Temporary download path (megadl saves the file with original name by default)
download_dir3 = "/content"
downloaded_file = os.path.join(download_dir, "CFE_a_levee_reference.tif")

# Target directory
target_dir3 = f'{Swin_UNETR_path}/data'
os.makedirs(target_dir3, exist_ok=True)

# Download file using megadl
# !megadl "{mega_url2}" --path "{download_dir3}"

# Move the file to target directory (if needed rename)
shutil.move(downloaded_file, os.path.join(target_dir3, "CFE_a_levee_reference.tif"))
print(f"File moved to: {target_dir3}")

Reference_data_path = os.path.join(target_dir3, "CFE_a_levee_reference.tif")
# Out:
# Downloaded CFE_a_levee_reference.tif
# File moved to: /content/2025_levees_DL/Swin_UNETR/data

# %%
import os
import numpy as np
import rasterio
from rasterio.enums import Resampling
from rasterio.warp import reproject
from rasterio.transform import Affine
from scipy.ndimage import binary_dilation, binary_erosion

# ------------------------------------------------------------
# Step 1. Read spatial coordinates from TFW
# ------------------------------------------------------------
def read_tfw_coordinates(tif_path):
    tfw_path = os.path.splitext(tif_path)[0] + ".tfw"
    if not os.path.exists(tfw_path):
        raise FileNotFoundError(f"World file not found: {tfw_path}")

    with open(tfw_path, "r") as f:
        lines = f.readlines()
    if len(lines) != 6:
        raise ValueError(f"Invalid world file format: {tfw_path}")

    # Parse six parameters
    A = float(lines[0])  # pixel size in X
    D = float(lines[1])  # rotation term
    B = float(lines[2])  # rotation term
    E = float(lines[3])  # pixel size in Y
    C = float(lines[4])  # X coordinate of center of upper-left pixel
    F = float(lines[5])  # Y coordinate of center of upper-left pixel

    transform = Affine(A, B, C, D, E, F)
    print("\n[TFW] Affine transform read from file:")

    return transform


# ------------------------------------------------------------
# Step 2. Align reference raster to predicted raster
# ------------------------------------------------------------

def align_reference_with_crs(reference_tif, predicted_tif, predicted_transform, dst_crs, output_path):
    with rasterio.open(predicted_tif) as pred:
        dst_width = pred.width
        dst_height = pred.height
        dst_profile = pred.profile.copy()

    with rasterio.open(reference_tif) as ref:
        if ref.crs is None:
            raise ValueError("Reference raster has no CRS — cannot reproject.")
        src_dtype = ref.dtypes[0]
        dest = np.zeros((dst_height, dst_width), dtype=src_dtype)

        reproject(
            source=rasterio.band(ref, 1),
            destination=dest,
            src_transform=ref.transform,
            src_crs=ref.crs,
            dst_transform=predicted_transform,
            dst_crs=dst_crs,
            resampling=Resampling.nearest,
            num_threads=2
        )

    dst_profile.update(
        dtype=src_dtype,
        count=1,
        compress="lzw",
        driver="GTiff",
        transform=predicted_transform,
        crs=dst_crs,
        width=dst_width,
        height=dst_height
    )

    with rasterio.open(output_path, "w", **dst_profile) as dst:
        dst.write(dest, 1)

    print(f"\nAligned reference raster saved to:\n{output_path}")
    return output_path



def align_reference(reference_tif, predicted_tif, predicted_transform, output_path):
    with rasterio.open(predicted_tif) as pred:
        dst_crs = pred.crs
        dst_width = pred.width
        dst_height = pred.height
        dst_profile = pred.profile.copy()

    with rasterio.open(reference_tif) as ref:
        if ref.crs is None:
            raise ValueError("Reference raster has no CRS — cannot reproject.")
        src_dtype = ref.dtypes[0]
        dest = np.zeros((dst_height, dst_width), dtype=src_dtype)

        reproject(
            source=rasterio.band(ref, 1),
            destination=dest,
            src_transform=ref.transform,
            src_crs=ref.crs,
            dst_transform=predicted_transform,
            dst_crs=dst_crs,
            resampling=Resampling.nearest,
            num_threads=2
        )

    dst_profile.update(
        dtype=src_dtype,
        count=1,
        compress="lzw",
        driver="GTiff",
        transform=predicted_transform,
        crs=dst_crs,
        width=dst_width,
        height=dst_height
    )

    with rasterio.open(output_path, "w", **dst_profile) as dst:
        dst.write(dest, 1)

    print(f"\nAligned reference raster saved to:\n{output_path}")
    return output_path


# ------------------------------------------------------------
# Step 3. Compare rasters
# ------------------------------------------------------------
def compare_rasters(reference_tif, predicted_tif, IoU_buf):
    with rasterio.open(reference_tif) as ref_src:
        ref_data = ref_src.read(1)
        profile = ref_src.profile

    with rasterio.open(predicted_tif) as pred_src:
        pred_data = pred_src.read(1)

    if ref_data.shape != pred_data.shape:
        raise ValueError("Rasters must have the same dimensions and alignment.")

    struct_element = np.ones((IoU_buf, IoU_buf))
    buffered_ref = binary_dilation(ref_data, structure=struct_element).astype(ref_data.dtype)
    eroded_pred_data = binary_erosion(pred_data, structure=struct_element).astype(pred_data.dtype)

    TP = (buffered_ref == 1) & (eroded_pred_data == 1)
    FP = (buffered_ref == 0) & (eroded_pred_data == 1)
    FN = (buffered_ref == 1) & (eroded_pred_data == 0)

    output_data = np.zeros_like(eroded_pred_data, dtype=np.int8)
    output_data[TP] = 1
    output_data[FP] = -1
    output_data[FN] = 2

    tp_count = np.sum(TP)
    fp_count = np.sum(FP)
    fn_count = np.sum(FN)

    precision = tp_count / (tp_count + fp_count) if (tp_count + fp_count) > 0 else 0
    recall = tp_count / (tp_count + fn_count) if (tp_count + fn_count) > 0 else 0
    f1_score = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    iou = tp_count / (tp_count + fp_count + fn_count) if (tp_count + fp_count + fn_count) > 0 else 0

    print(f"\n--- Evaluation Metrics ---")
    print(f"IoU:        {iou:.4f}")
    print(f"Precision:  {precision:.4f}")
    print(f"Recall:     {recall:.4f}")
    print(f"F1 Score:   {f1_score:.4f}")

    output_path = predicted_tif.replace(".tif", f"_comparison_buf{IoU_buf}.tif")
    profile.update(dtype=rasterio.int8, count=1)

    with rasterio.open(output_path, "w", **profile) as dst:
        dst.write(output_data, 1)

    print(f"Comparison raster saved to:\n{output_path}")


# ------------------------------------------------------------
# Step 4. Main workflow
# ------------------------------------------------------------
def main():
    reference_tif = Reference_data_path
    #reference_tif = input("Enter path to reference data: ").strip('"') # If manual selection is needed
    predicted_tif = closing_tif_path
    #predicted_tif = input("Enter path to predicted data: ").strip('"') # If manual selection is needed

    IoU_buf = 1  # buffer size for dilation/erosion

    # Step 1: Read transform from TFW file
    predicted_transform = read_tfw_coordinates(predicted_tif)

    # Step 1b: Define CRS manually (replace EPSG code as needed!)
    from rasterio.crs import CRS
    dst_crs = CRS.from_epsg(4326)   #

    # Step 2: Align reference raster
    aligned_ref_path = os.path.splitext(predicted_tif)[0] + "_ref_aligned.tif"
    aligned_ref = align_reference_with_crs(reference_tif, predicted_tif, predicted_transform, dst_crs, aligned_ref_path)

    # Step 3: Compare rasters
    compare_rasters(aligned_ref, predicted_tif, IoU_buf)



if __name__ == "__main__":
    main()
# Out:
# [TFW] Affine transform read from file:
#
# Aligned reference raster saved to:
# /content/2025_levees_DL/Swin_UNETR/results/Swin_UNETR/Aug/Filtered/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48_swinunetr_closing_ref_aligned.tif
#
# --- Evaluation Metrics ---
# IoU:        0.3605
# Precision:  0.4661
# Recall:     0.6142
# F1 Score:   0.5300
# Comparison raster saved to:
# /content/2025_levees_DL/Swin_UNETR/results/Swin_UNETR/Aug/Filtered/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48_swinunetr_closing_comparison_buf1.tif

# %% [markdown]
# 5. Visualize the results

# %%
#!pip install leaflet
# !pip install leafmap
# !pip install localtileserver
# Out:
# Collecting leafmap
#   Downloading leafmap-0.54.0-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.9.18)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.12.45)
# Requirement already satisfied: duckdb in /usr/local/lib/python3.12/dist-packages (from leafmap) (1.3.2)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.20.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from leafmap) (5.2.0)
# Collecting geojson (from leafmap)
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from leafmap) (1.1.1)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from leafmap) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.20.0)
# Collecting ipyvuetify (from leafmap)
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap) (7.7.1)
# Collecting maplibre (from leafmap)
#   Downloading maplibre-0.3.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from leafmap) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from leafmap) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from leafmap) (2.2.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap) (5.24.1)
# Collecting pystac-client (from leafmap)
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap) (7.3.2)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap) (0.10.2)
# Collecting whiteboxgui (from leafmap)
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from leafmap) (2025.4.0)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap) (0.14.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap) (4.15.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap) (3.0.15)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from bqplot->leafmap) (0.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->leafmap) (2025.2)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium->leafmap) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium->leafmap) (3.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium->leafmap) (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap) (3.20.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap) (4.67.1)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->leafmap) (0.11.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from geopandas->leafmap) (25.0)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->leafmap) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->leafmap) (2.1.2)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet->leafmap) (0.20.0)
# Collecting ipyvue<2,>=1.7 (from ipyvuetify->leafmap)
#   Downloading ipyvue-1.11.3-py2.py3-none-any.whl.metadata (987 bytes)
# Collecting eval-type-backport (from maplibre->leafmap)
#   Downloading eval_type_backport-0.2.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: pydantic>=2.5.3 in /usr/local/lib/python3.12/dist-packages (from maplibre->leafmap) (2.11.10)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->leafmap) (8.5.0)
# Collecting pystac>=1.10.0 (from pystac[validation]>=1.10.0->pystac-client->leafmap)
#   Downloading pystac-1.14.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.12/dist-packages (from whiteboxgui->leafmap) (0.2.2)
# Collecting whitebox (from whiteboxgui->leafmap)
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap) (6.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (75.2.0)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->leafmap)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium->leafmap) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->leafmap) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->leafmap) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.5.3->maplibre->leafmap) (0.4.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyogrio>=0.7.2->geopandas->leafmap) (2025.10.5)
# Requirement already satisfied: jsonschema~=4.18 in /usr/local/lib/python3.12/dist-packages (from pystac[validation]>=1.10.0->pystac-client->leafmap) (4.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->leafmap) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium->leafmap) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium->leafmap) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium->leafmap) (2.5.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap) (6.5.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->leafmap) (2.8)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->leafmap) (1.7.1)
# Requirement already satisfied: Click>=6.0 in /usr/local/lib/python3.12/dist-packages (from whitebox->whiteboxgui->leafmap) (8.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema~=4.18->pystac[validation]>=1.10.0->pystac-client->leafmap) (0.27.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap) (5.8.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.3.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->leafmap) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->leafmap) (0.2.14)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->leafmap) (4.5.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.2.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (2.21.2)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (2.23)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (4.11.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (24.11.1)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.3.0)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap) (2.9.0.20251008)
# Downloading leafmap-0.54.0-py2.py3-none-any.whl (603 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 603.9/603.9 kB 28.4 MB/s eta 0:00:00
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 96.1 MB/s eta 0:00:00
# Downloading maplibre-0.3.5-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 73.0 MB/s eta 0:00:00
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 4.7 MB/s eta 0:00:00
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 13.1 MB/s eta 0:00:00
# Downloading ipyvue-1.11.3-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 17.9 MB/s eta 0:00:00
# Downloading pystac-1.14.1-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.7/207.7 kB 16.9 MB/s eta 0:00:00
# Downloading eval_type_backport-0.2.2-py3-none-any.whl (5.8 kB)
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 9.8 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 80.8 MB/s eta 0:00:00
# Installing collected packages: whitebox, jedi, geojson, eval-type-backport, pystac, maplibre, pystac-client, ipyvue, whiteboxgui, ipyvuetify, leafmap
# Successfully installed eval-type-backport-0.2.2 geojson-3.2.0 ipyvue-1.11.3 ipyvuetify-1.11.3 jedi-0.19.2 leafmap-0.54.0 maplibre-0.3.5 pystac-1.14.1 pystac-client-0.9.0 whitebox-2.3.6 whiteboxgui-2.3.0
# Collecting localtileserver
#   Downloading localtileserver-0.10.6-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from localtileserver) (8.3.0)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver) (3.1.2)
# Collecting Flask-Caching (from localtileserver)
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver)
#   Downloading flask_cors-6.0.1-py3-none-any.whl.metadata (5.3 kB)
# Collecting flask-restx>=1.3.0 (from localtileserver)
#   Downloading flask_restx-1.3.2-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver)
#   Downloading rio_tiler-7.9.2-py3-none-any.whl.metadata (12 kB)
# Collecting rio-cogeo (from localtileserver)
#   Downloading rio_cogeo-5.4.2-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from localtileserver) (2.32.4)
# Collecting server-thread (from localtileserver)
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from localtileserver) (0.10.2)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.12/dist-packages (from localtileserver) (3.1.3)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver) (3.0.3)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver)
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver) (4.25.1)
# Requirement already satisfied: referencing in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver) (0.37.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver) (6.5.2)
# Collecting cachelib>=0.9.0 (from Flask-Caching->localtileserver)
#   Downloading cachelib-0.13.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->localtileserver) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->localtileserver) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->localtileserver) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->localtileserver) (2025.10.5)
# Requirement already satisfied: rasterio>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from rio-cogeo->localtileserver) (1.4.3)
# Collecting morecantile<7.0,>=5.0 (from rio-cogeo->localtileserver)
#   Downloading morecantile-6.2.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pydantic~=2.0 in /usr/local/lib/python3.12/dist-packages (from rio-cogeo->localtileserver) (2.11.10)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver) (25.4.0)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver) (5.5.2)
# Collecting color-operations (from rio-tiler->localtileserver)
#   Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver) (0.28.1)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver) (2.14.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver) (2.0.2)
# Requirement already satisfied: pystac<2.0,>=1.9 in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver) (1.14.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver) (4.15.0)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from server-thread->localtileserver) (0.37.0)
# Requirement already satisfied: pyproj<4.0,>=3.1 in /usr/local/lib/python3.12/dist-packages (from morecantile<7.0,>=5.0->rio-cogeo->localtileserver) (3.7.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic~=2.0->rio-cogeo->localtileserver) (0.4.2)
# Requirement already satisfied: python-dateutil>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from pystac<2.0,>=1.9->rio-tiler->localtileserver) (2.9.0.post0)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.3.3->rio-cogeo->localtileserver) (2.4.0)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.3.3->rio-cogeo->localtileserver) (0.7.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.3.3->rio-cogeo->localtileserver) (1.1.1.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio>=1.3.3->rio-cogeo->localtileserver) (3.2.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->rio-tiler->localtileserver) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->rio-tiler->localtileserver) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->rio-tiler->localtileserver) (0.16.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver) (0.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7.0->pystac<2.0,>=1.9->rio-tiler->localtileserver) (1.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx->rio-tiler->localtileserver) (1.3.1)
# Downloading localtileserver-0.10.6-py3-none-any.whl (17.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 66.4 MB/s eta 0:00:00
# Downloading flask_restx-1.3.2-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 112.7 MB/s eta 0:00:00
# Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Downloading flask_cors-6.0.1-py3-none-any.whl (13 kB)
# Downloading rio_cogeo-5.4.2-py3-none-any.whl (21 kB)
# Downloading rio_tiler-7.9.2-py3-none-any.whl (269 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.0/270.0 kB 28.6 MB/s eta 0:00:00
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 6.1 MB/s eta 0:00:00
# Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Downloading morecantile-6.2.0-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 5.5 MB/s eta 0:00:00
# Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 25.0 MB/s eta 0:00:00
# Installing collected packages: aniso8601, color-operations, cachelib, server-thread, morecantile, flask-cors, Flask-Caching, rio-tiler, rio-cogeo, flask-restx, localtileserver
# Successfully installed Flask-Caching-2.3.1 aniso8601-10.0.1 cachelib-0.13.0 color-operations-0.2.0 flask-cors-6.0.1 flask-restx-1.3.2 localtileserver-0.10.6 morecantile-6.2.0 rio-cogeo-5.4.2 rio-tiler-7.9.2 server-thread-0.3.0

# %%
import leafmap

# Map center coordinates
latitude = 31.52806
longitude = 65.24722

# Initialize map
m = leafmap.Map(center=[latitude, longitude], zoom=14)

# Raster path
raster_path = "/content/2025_levees_DL/Swin_UNETR/results/Swin_UNETR/Aug/Filtered/CFE_a_selected_L5_S2_S1_MSRM_PCA_GLO_N48_swinunetr_closing_comparison_buf1.tif"

# Define palette
palette = [
    "#e5350e",  # -1 = False Positives (red)
    "#0dff0d",  #  1 = True Positives (green)
    "#729bff",  #  2 = False Negatives (blue)
]

# ✅ Correct syntax for add_raster
m.add_raster(
    raster_path,    # source (positional)
    palette=palette,
    vmin=-1,
    vmax=2,
    nodata=0,
    layer_name="Detection Results",
)

# Add legend
legend_dict = {
    "False Positives (-1)": "#e5350e",
    "True Positives (1)": "#0dff0d",
    "False Negatives (2)": "#729bff",
}
m.add_legend(title="Detection Results", legend_dict=legend_dict)

# Add layer control for interactivity
m.add_layer_control()

# Show map
m
# Out:
# Map(center=[32.3286605, 44.559043], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title'…
